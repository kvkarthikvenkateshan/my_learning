# %% [markdown]
# # Data Analytics with Python

# %% [markdown]
# Importing pandas and Numpy modules

# %%
import numpy as np
import pandas as pd

# %%
a = [10,54,34,67,81,62,33,84,5]

# %%
b = pd.Series(a) #Converting a list to a series
b
# Out:
# 0    10
# 1    54
# 2    34
# 3    67
# 4    81
# 5    62
# 6    33
# 7    84
# 8     5
# dtype: int64

# %%
b[5] # Accessing an element from the series using the index
# Out:
# 62

# %%
b.loc[5] #Using .loc attribute
# Out:
# 62

# %%
b.iloc[5] #using .iloc attribute
# Out:
# 62

# %%
c = pd.Series([2,3,1,4])
c
# Out:
# 0    2
# 1    3
# 2    1
# 3    4
# dtype: int64

# %%
c[0]
# Out:
# 2

# %%
c[3]
# Out:
# 4

# %%
z = np.random.randint(0,10,2)
z #here the 1st Arg is lower limit and 2nd Arg is the upper limit and the 3rd one is the number of randam numbers to generated
# Out:
# array([0, 0])

# %%
d = pd.Series(z) # Creating a series using numpy

# %%
d
# Out:
# 0    0
# 1    0
# dtype: int32

# %%
len(d)
# Out:
# 2

# %%
np.random.randint(1,100,3)
# Out:
# array([47, 45,  1])

# %%
e = pd.Series(np.random.randint(1,100,10))
print(e)
for i,j in e.iteritems():
    print (i,j)
# Out:
# 0    96
# 1    84
# 2    75
# 3    58
# 4    54
# 5    19
# 6    73
# 7    73
# 8    29
# 9    86
# dtype: int32
# 0 96
# 1 84
# 2 75
# 3 58
# 4 54
# 5 19
# 6 73
# 7 73
# 8 29
# 9 86

# %%
# %%timeit -n 100 # Calculating the time needed to execute this block
e = pd.Series(np.random.randint(1,100,100))
for i,j in e.iteritems():
    e.loc[i] = j+2
# Out:
# 100 loops, best of 3: 6.08 ms per loop

# %%
# %%timeit -n 100 # Calculating the time needed to execute this block
e = pd.Series(np.random.randint(1,100,100))
e += 2
# Out:
# 100 loops, best of 3: 162 µs per loop

# %%
c
# Out:
# 0    2
# 1    3
# 2    1
# 3    4
# dtype: int64

# %%
c.loc['apple'] = 1 # Adding an Element to a series

# %%
c
# Out:
# 0        2
# 1        3
# 2        1
# 3        4
# apple    1
# dtype: int64

# %%
c.loc[0] = 133 # assigning a new value to an index in the series
c
# Out:
# 0        133
# 1          3
# 2          1
# 3          4
# apple      1
# dtype: int64

# %% [markdown]
# It is possible to add a new value to the series the value can be a sequence also

# %%
c.loc['water'] = [1,2,3,41]
c
# Out:
# 0                  133
# 1                    3
# 2                    1
# 3                    4
# apple                1
# water    [1, 2, 3, 41]
# dtype: object

# %%
c['air'] = 'oxygen'
c
# Out:
# 0                  133
# 1                    3
# 2                    1
# 3                    4
# apple                1
# water    [1, 2, 3, 41]
# air             oxygen
# dtype: object

# %%
f = pd.Series([1,[2,3,4],[123,456],89])
f
# Out:
# 0             1
# 1     [2, 3, 4]
# 2    [123, 456]
# 3            89
# dtype: object

# %%
original_sports = pd.Series({'Kabbadi':'India','Cricket':'Srilanka','Swimming':'South Africa','Polo':'Bangladesh'})
original_sports
# Out:
# Cricket         Srilanka
# Kabbadi            India
# Polo          Bangladesh
# Swimming    South Africa
# dtype: object

# %%
cricket_loving_countries = pd.Series(['England','West Indies','Kenya','Afghan','Bangladesh','Pakistan'], index = ['Cricket','Cricket','Cricket','Cricket','Cricket','Cricket',])
cricket_loving_countries
# Out:
# Cricket        England
# Cricket    West Indies
# Cricket          Kenya
# Cricket         Afghan
# Cricket     Bangladesh
# Cricket       Pakistan
# dtype: object

# %%
all_countires = original_sports.append(cricket_loving_countries)
all_countires
# Out:
# Cricket         Srilanka
# Kabbadi            India
# Polo          Bangladesh
# Swimming    South Africa
# Cricket          England
# Cricket      West Indies
# Cricket            Kenya
# Cricket           Afghan
# Cricket       Bangladesh
# Cricket         Pakistan
# dtype: object

# %% [markdown]
# while appending one series to another it can be seen that if there are common element in both the series but with different indices then the resultant series will have both the values and both the indices.
# In the above exapmle bangladesh is common in both the series and it has polo as it's index in the first one while it has cricket as it's index in the second so the resultant will have bangladesh as the value for both the index cricket and polo

# %%
all_countires.loc['Cricket']
# Out:
# Cricket       Srilanka
# Cricket        England
# Cricket    West Indies
# Cricket          Kenya
# Cricket         Afghan
# Cricket     Bangladesh
# Cricket       Pakistan
# dtype: object

# %%
all_countires
# Out:
# Cricket         Srilanka
# Kabbadi            India
# Polo          Bangladesh
# Swimming    South Africa
# Cricket          England
# Cricket      West Indies
# Cricket            Kenya
# Cricket           Afghan
# Cricket       Bangladesh
# Cricket         Pakistan
# dtype: object

# %%
person1 = pd.Series({'Name': 'Harvey Specter',
                    'Age': 36,'Employed': ' Pearson Specter'})
person1
# Out:
# Age                       36
# Employed     Pearson Specter
# Name          Harvey Specter
# dtype: object

# %%
person2 = pd.Series({'Name': 'Jassica Pearson',
                    'Age': 40,'Employed': 'Pearson Specter'})
person2
# Out:
# Age                      40
# Employed    Pearson Specter
# Name        Jassica Pearson
# dtype: object

# %%
person3 = pd.Series({'Name': 'Mike Ross',
                    'Age': 27,'Employed': 'Clinic'})
person3
# Out:
# Age                27
# Employed       Clinic
# Name        Mike Ross
# dtype: object

# %%
df1 = pd.DataFrame([person1,person2,person3], index = ['C1','C1','C2'])
df1
# Out:
#     Age          Employed             Name
# C1   36   Pearson Specter   Harvey Specter
# C1   40   Pearson Specter  Jassica Pearson
# C2   27            Clinic        Mike Ross

# %% [markdown]
# On using the loc attribute on a Index value that is unique a series is returned with the column names from DataFrame as the index of series

# %%
df1.loc['C2']
# Out:
# Age                27
# Employed       Clinic
# Name        Mike Ross
# Name: C2, dtype: object

# %%
type(df1.loc['C2'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# The index value need not be unique and in case there are multiple series with the same index name then on using the loc attribute a DataFrame is returned as shown below

# %%
df1.loc['C1']
# Out:
#     Age          Employed             Name
# C1   36   Pearson Specter   Harvey Specter
# C1   40   Pearson Specter  Jassica Pearson

# %%
df1
# Out:
#     Age          Employed             Name
# C1   36   Pearson Specter   Harvey Specter
# C1   40   Pearson Specter  Jassica Pearson
# C2   27            Clinic        Mike Ross

# %% [markdown]
# It is possible to have all the elements from a column be printed at once using the index operator where the name of the column is given inside the big brackets, in all these cases the correspondiing index is also printed along with the column name.
# The return type will have column name along with the datatype of the value.

# %%
df1['Age']
# Out:
# C1    36
# C1    40
# C2    27
# Name: Age, dtype: int64

# %%
df1['Employed']
# Out:
# C1     Pearson Specter
# C1     Pearson Specter
# C2              Clinic
# Name: Employed, dtype: object

# %% [markdown]
# df1.loc['Age']
# '''The .loc attribute takes the index as the value inside square bracket and if the name of the column is given
# it throw a key error'''

# %% [markdown]
# It is possible to find out a value in a paticular cell of a dataframe by using the loc operator along with the name of the column, if the index and the column are unique then a single value in the cell is returned and if the index value is not unique then all the values that maps to indices cross Column name will be printed as output and in this case the output is a series

# %%
df1.loc['C2','Age']
# Out:
# 27

# %%
df1.loc['C1','Age']
# Out:
# C1    36
# C1    40
# Name: Age, dtype: int64

# %% [markdown]
# In case there is no index provided while creating a data frame then the index will start from 0

# %%
df2 = pd.DataFrame([person1,person2,person3])
df2
# Out:
#    Age          Employed             Name
# 0   36   Pearson Specter   Harvey Specter
# 1   40   Pearson Specter  Jassica Pearson
# 2   27            Clinic        Mike Ross

# %% [markdown]
# The indexig operator [] takes the name of column as the argument and returns all the rows under that column as the output

# %%
df2['Employed']
# Out:
# 0     Pearson Specter
# 1     Pearson Specter
# 2              Clinic
# Name: Employed, dtype: object

# %% [markdown]
# The Transpose of a DataFrame is obtained using the .T operator on the dataframe.
# After doing the Transpose column names and index are interchanged [i.e. all column names are now row names and all row names are column names]

# %%
df2.T
# Out:
#                          0                1          2
# Age                     36               40         27
# Employed   Pearson Specter  Pearson Specter     Clinic
# Name        Harvey Specter  Jassica Pearson  Mike Ross

# %%
df2
# Out:
#    Age          Employed             Name
# 0   36   Pearson Specter   Harvey Specter
# 1   40   Pearson Specter  Jassica Pearson
# 2   27            Clinic        Mike Ross

# %% [markdown]
# The transpose of a Dataframe will return a view of the transposed df and will not change the origianl dataframe

# %% [markdown]
# Sub setting a df from the original DF using the .loc operator
#
# If it is desird to a subset df with multiple with only selected rows of df then use two lists inside the .loc[], where the 1st list stands for rows of df and 2nd list for the name of the columns

# %%
df2.loc[[1,2],['Age','Name']]
# Out:
#    Age             Name
# 1   40  Jassica Pearson
# 2   27        Mike Ross

# %%
df2.loc[[0],['Age','Name']]
# Out:
#    Age            Name
# 0   36  Harvey Specter

# %%
df1
# Out:
#     Age          Employed             Name
# C1   36   Pearson Specter   Harvey Specter
# C1   40   Pearson Specter  Jassica Pearson
# C2   27            Clinic        Mike Ross

# %% [markdown]
# # Chaining with .loc but the column name is given as a separate index value

# %% [markdown]
# Chaining also does the same what a .loc[index, columnname] would return, but the difference here is that the chaining returns a copy of the dataFrame where as in case of .loc[index, columnname] returns a view of the same data frame.
#
# In case just a view of the Data Frame is what is intended the it is better to use .loc[index, columnname] than chaining, coz chaining takes a longer time to execute.

# %%
df1.loc['C1']['Employed']
# Out:
# C1     Pearson Specter
# C1     Pearson Specter
# Name: Employed, dtype: object

# %% [markdown]
# Creating a dataframe by Slicing the rows and explicitly mentioned the name of the column names in a list if more than one column name is required in the view.

# %%
df1.loc[: ,['Name','Age']]
# Out:
#                Name  Age
# C1   Harvey Specter   36
# C1  Jassica Pearson   40
# C2        Mike Ross   27

# %% [markdown]
# loc operator takes two arguments
#
# 1st : index name or row name
#
# 2nd : list of column names

# %% [markdown]
# ## Dropping rows from the DataFrame using drop

# %% [markdown]
# Here the drop function will not change the original Dataframe instead a copy of the df1 has been created and in that copy the row with the index C2 is dropped

# %%
df1.drop('C2')
# Out:
#     Age          Employed             Name
# C1   36   Pearson Specter   Harvey Specter
# C1   40   Pearson Specter  Jassica Pearson

# %%
df1
# Out:
#     Age          Employed             Name
# C1   36   Pearson Specter   Harvey Specter
# C1   40   Pearson Specter  Jassica Pearson
# C2   27            Clinic        Mike Ross

# %% [markdown]
# Drop method has two optional parameters, the first one is "inplace" and by default it's value is "false" and if "inplace" is set to true the it will update the df and not the copy of the dataframe.
#
# The second paraeter is "axis", by default it value is zero indicating a row axis.
# If it is desiderd to drop a column then axis has to be made 1 along with the name of the column name to be dropped.

# %%
df1.drop('C1',inplace = True)

# %%
df1
# Out:
#     Age Employed       Name
# C2   27   Clinic  Mike Ross

# %%
df1.drop('Employed',axis = 1)
# Out:
#     Age       Name
# C2   27  Mike Ross

# %%
df1 ['Location'] = 'New York'

# %%
df1
# Out:
#     Age Employed       Name  Location
# C2   27   Clinic  Mike Ross  New York

# %%
df1 = pd.DataFrame([person1,person2,person3], index = ['C1','C1','C2'])
df1
# Out:
#     Age          Employed             Name
# C1   36   Pearson Specter   Harvey Specter
# C1   40   Pearson Specter  Jassica Pearson
# C2   27            Clinic        Mike Ross

# %%
df1 ['Location'] = 'New York'
df1
# Out:
#     Age          Employed             Name  Location
# C1   36   Pearson Specter   Harvey Specter  New York
# C1   40   Pearson Specter  Jassica Pearson  New York
# C2   27            Clinic        Mike Ross  New York

# %% [markdown]
# ### Dataframe Indexing and loading

# %%
age = df1['Age'] 
age
# Out:
# C1    36
# C1    40
# C2    27
# Name: Age, dtype: int64

# %% [markdown]
# ### Broadcasting

# %%
age += 2 # This concept is called broadcasting
df1
# Out:
#     Age          Employed             Name  Location
# C1   38   Pearson Specter   Harvey Specter  New York
# C1   42   Pearson Specter  Jassica Pearson  New York
# C2   29            Clinic        Mike Ross  New York

# %% [markdown]
# During broadcasting the original dataframe is changed and not a copy of it, one needs to be careful while performing broadcasting on the dataframe

# %%
df3 = pd.read_csv('olympics.csv')
df3.head()
# Out:
#                    0         1     2     3     4      5         6     7     8  \
# 0                NaN  № Summer  01 !  02 !  03 !  Total  № Winter  01 !  02 !
# 1  Afghanistan (AFG)        13     0     0     2      2         0     0     0
# 2      Algeria (ALG)        12     5     2     8     15         3     0     0
# 3    Argentina (ARG)        23    18    24    28     70        18     0     0
# 4      Armenia (ARM)         5     1     2     9     12         6     0     0
#
#       9     10       11    12    13    14              15
# 0  03 !  Total  № Games  01 !  02 !  03 !  Combined total
# 1     0      0       13     0     0     2               2
# 2     0      0       15     5     2     8              15
# 3     0      0       41    18    24    28              70
# 4     0      0       11     1     2     9              12

# %%
df4 = pd.read_csv('olympics.csv', index_col = 0, skiprows = 1)
df4.head()
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %%
df4.columns
# Out:
# Index(['№ Summer', '01 !', '02 !', '03 !', 'Total', '№ Winter', '01 !.1',
#        '02 !.1', '03 !.1', 'Total.1', '№ Games', '01 !.2', '02 !.2', '03 !.2',
#        'Combined total'],
#       dtype='object')

# %%
df4.index
# Out:
# Index(['Afghanistan (AFG)', 'Algeria (ALG)', 'Argentina (ARG)',
#        'Armenia (ARM)', 'Australasia (ANZ) [ANZ]', 'Australia (AUS) [AUS] [Z]',
#        'Austria (AUT)', 'Azerbaijan (AZE)', 'Bahamas (BAH)', 'Bahrain (BRN)',
#        ...
#        'Uzbekistan (UZB)', 'Venezuela (VEN)', 'Vietnam (VIE)',
#        'Virgin Islands (ISV)', 'Yugoslavia (YUG) [YUG]',
#        'Independent Olympic Participants (IOP) [IOP]', 'Zambia (ZAM) [ZAM]',
#        'Zimbabwe (ZIM) [ZIM]', 'Mixed team (ZZX) [ZZX]', 'Totals'],
#       dtype='object', length=147)

# %% [markdown]
# .cloumns attribute gives the names of all the columns in the datatframe
#
# .index attribute gives the names of all the index or row name in the datatframe

# %%
for col in df4.columns:
    print(col)
    if col[0] == '№':
        print('the length is ',len(col[0]))
# Out:
# № Summer
# the length is  1
# 01 !
# 02 !
# 03 !
# Total
# № Winter
# the length is  1
# 01 !.1
# 02 !.1
# 03 !.1
# Total.1
# № Games
# the length is  1
# 01 !.2
# 02 !.2
# 03 !.2
# Combined total

# %%
for col in df4.columns:
    if col[:2] == '01':
        df4.rename(columns = {col: 'Gold'+col[4:]}, inplace = True)
    elif col[:2] == '02':
        df4.rename(columns = {col: 'Silver'+col[4:]}, inplace = True)
    elif col[:2] == '03':
        df4.rename(columns = {col: 'Bronze'+col[4:]}, inplace = True)
    elif col[:1] == '№':
        df4.rename(columns = {col: '#'+col[2:]}, inplace = True)

df4.head()
# Out:
#                          #Summer  Gold  Silver  Bronze  Total  #Winter  \
# Afghanistan (AFG)             13     0       0       2      2        0
# Algeria (ALG)                 12     5       2       8     15        3
# Argentina (ARG)               23    18      24      28     70       18
# Armenia (ARM)                  5     1       2       9     12        6
# Australasia (ANZ) [ANZ]        2     3       4       5     12        0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  #Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0      13       0
# Algeria (ALG)                 0         0         0        0      15       5
# Argentina (ARG)               0         0         0        0      41      18
# Armenia (ARM)                 0         0         0        0      11       1
# Australasia (ANZ) [ANZ]       0         0         0        0       2       3
#
#                          Silver.2  Bronze.2  Combined total
# ...

# %% [markdown]
# ## Boolena Masking: Boolean masking is the heart of fast and efficient querying in numpy.
# A boolena mask is an array which can be one dimensional like a series or two dimensional like a Dateframe,where each of the value in the arrary are True or False, this array is overlaid on the data structure that we are querying.

# %% [markdown]
# ### Querying a Dataframe

# %%
df4['Gold'] > 0
# Out:
# Afghanistan (AFG)                               False
# Algeria (ALG)                                    True
# Argentina (ARG)                                  True
# Armenia (ARM)                                    True
# Australasia (ANZ) [ANZ]                          True
# Australia (AUS) [AUS] [Z]                        True
# Austria (AUT)                                    True
# Azerbaijan (AZE)                                 True
# Bahamas (BAH)                                    True
# Bahrain (BRN)                                   False
# Barbados (BAR) [BAR]                            False
# Belarus (BLR)                                    True
# Belgium (BEL)                                    True
# Bermuda (BER)                                   False
# Bohemia (BOH) [BOH] [Z]                         False
# Botswana (BOT)                                  False
# Brazil (BRA)                                     True
# ...

# %%
only_gold = df4.where(df4['Gold'] > 0)

# %%
only_gold.head(20)
# Out:
#                                  #Summer   Gold  Silver  Bronze  Total  \
# Afghanistan (AFG)                    NaN    NaN     NaN     NaN    NaN
# Algeria (ALG)                       12.0    5.0     2.0     8.0   15.0
# Argentina (ARG)                     23.0   18.0    24.0    28.0   70.0
# Armenia (ARM)                        5.0    1.0     2.0     9.0   12.0
# Australasia (ANZ) [ANZ]              2.0    3.0     4.0     5.0   12.0
# Australia (AUS) [AUS] [Z]           25.0  139.0   152.0   177.0  468.0
# Austria (AUT)                       26.0   18.0    33.0    35.0   86.0
# Azerbaijan (AZE)                     5.0    6.0     5.0    15.0   26.0
# Bahamas (BAH)                       15.0    5.0     2.0     5.0   12.0
# Bahrain (BRN)                        NaN    NaN     NaN     NaN    NaN
# Barbados (BAR) [BAR]                 NaN    NaN     NaN     NaN    NaN
# Belarus (BLR)                        5.0   12.0    24.0    39.0   75.0
# ...

# %% [markdown]
# Only those cells which have a number of gold medal's greater than 0 will have a value in them and the rest of them will have Nan.
#
# Further these Nan cells can be dropped from the DF using .dropna
#
# It is to be noted that for any computation purpose the cell with Nan will not be considered

# %%
only_gold['Gold'].count()
# Out:
# 100

# %%
df4['Gold'].count()
# Out:
# 147

# %%
only_gold = only_gold.dropna()

# %%
only_gold.head()
# Out:
#                            #Summer   Gold  Silver  Bronze  Total  #Winter  \
# Algeria (ALG)                 12.0    5.0     2.0     8.0   15.0      3.0
# Argentina (ARG)               23.0   18.0    24.0    28.0   70.0     18.0
# Armenia (ARM)                  5.0    1.0     2.0     9.0   12.0      6.0
# Australasia (ANZ) [ANZ]        2.0    3.0     4.0     5.0   12.0      0.0
# Australia (AUS) [AUS] [Z]     25.0  139.0   152.0   177.0  468.0     18.0
#
#                            Gold.1  Silver.1  Bronze.1  Total.1  #Games  \
# Algeria (ALG)                 0.0       0.0       0.0      0.0    15.0
# Argentina (ARG)               0.0       0.0       0.0      0.0    41.0
# Armenia (ARM)                 0.0       0.0       0.0      0.0    11.0
# Australasia (ANZ) [ANZ]       0.0       0.0       0.0      0.0     2.0
# Australia (AUS) [AUS] [Z]     5.0       3.0       4.0     12.0    43.0
#
#                            Gold.2  Silver.2  Bronze.2  Combined total
# ...

# %%
'''It is not madatory to make use .where function for doing the boolean masking,
instead the same can be achieved in the below way also.'''
only_gold1 = df4[df4['Gold'] > 0]
only_gold1
# Out:
#                                      #Summer  Gold  Silver  Bronze  Total  \
# Algeria (ALG)                             12     5       2       8     15
# Argentina (ARG)                           23    18      24      28     70
# Armenia (ARM)                              5     1       2       9     12
# Australasia (ANZ) [ANZ]                    2     3       4       5     12
# Australia (AUS) [AUS] [Z]                 25   139     152     177    468
# Austria (AUT)                             26    18      33      35     86
# Azerbaijan (AZE)                           5     6       5      15     26
# Bahamas (BAH)                             15     5       2       5     12
# Belarus (BLR)                              5    12      24      39     75
# Belgium (BEL)                             25    37      52      53    142
# Brazil (BRA)                              21    23      30      55    108
# Bulgaria (BUL) [H]                        19    51      85      78    214
# ...

# %%
only_silver = df4[df4['Silver'] > 0]
only_silver
# Out:
#                                               #Summer  Gold  Silver  Bronze  \
# Algeria (ALG)                                      12     5       2       8
# Argentina (ARG)                                    23    18      24      28
# Armenia (ARM)                                       5     1       2       9
# Australasia (ANZ) [ANZ]                             2     3       4       5
# Australia (AUS) [AUS] [Z]                          25   139     152     177
# Austria (AUT)                                      26    18      33      35
# Azerbaijan (AZE)                                    5     6       5      15
# Bahamas (BAH)                                      15     5       2       5
# Belarus (BLR)                                       5    12      24      39
# Belgium (BEL)                                      25    37      52      53
# Bohemia (BOH) [BOH] [Z]                             3     0       1       3
# ...

# %%
only_silver1 = df4.where(df4['Silver'] > 0)
only_silver1
# Out:
#                                               #Summer    Gold  Silver  Bronze  \
# Afghanistan (AFG)                                 NaN     NaN     NaN     NaN
# Algeria (ALG)                                    12.0     5.0     2.0     8.0
# Argentina (ARG)                                  23.0    18.0    24.0    28.0
# Armenia (ARM)                                     5.0     1.0     2.0     9.0
# Australasia (ANZ) [ANZ]                           2.0     3.0     4.0     5.0
# Australia (AUS) [AUS] [Z]                        25.0   139.0   152.0   177.0
# Austria (AUT)                                    26.0    18.0    33.0    35.0
# Azerbaijan (AZE)                                  5.0     6.0     5.0    15.0
# Bahamas (BAH)                                    15.0     5.0     2.0     5.0
# Bahrain (BRN)                                     NaN     NaN     NaN     NaN
# Barbados (BAR) [BAR]                              NaN     NaN     NaN     NaN
# ...

# %% [markdown]
# There is difference between using .where operator and df[df[]].
#
# In case of .where() function the returned dataframe has Nan values in cells which donesn't fulfill the given conditon and these rows can be removed from the dataframe by using .dropna(), where as in case of df[df['Column_name'] condition], the returned dataframe doen't have Nan values and it has only those rows which satisfied the given condition.

# %% [markdown]
# ### Using | and & operators on Dataframes

# %%
len(df4[(df4['Gold'] > 0 ) | df4['Gold.1'] > 0])
# Out:
# 101

# %%
df4[(df4['Gold.1'] > 0) & (df4['Gold'] == 0)]
# Out:
#                      #Summer  Gold  Silver  Bronze  Total  #Winter  Gold.1  \
# Liechtenstein (LIE)       16     0       0       0      0       18       2
#
#                      Silver.1  Bronze.1  Total.1  #Games  Gold.2  Silver.2  \
# Liechtenstein (LIE)         2         5        9      34       2         2
#
#                      Bronze.2  Combined total
# Liechtenstein (LIE)         5               9

# %% [markdown]
# Here we get all the index name by using .index on df4 and once all the index name is obtained it is assigned to a new column name called "country"

# %%
df4['Country'] = df4.index
df4.head()
# Out:
#                          #Summer  Gold  Silver  Bronze  Total  #Winter  \
# Afghanistan (AFG)             13     0       0       2      2        0
# Algeria (ALG)                 12     5       2       8     15        3
# Argentina (ARG)               23    18      24      28     70       18
# Armenia (ARM)                  5     1       2       9     12        6
# Australasia (ANZ) [ANZ]        2     3       4       5     12        0
#
#                          Gold.1  Silver.1  Bronze.1  Total.1  #Games  Gold.2  \
# Afghanistan (AFG)             0         0         0        0      13       0
# Algeria (ALG)                 0         0         0        0      15       5
# Argentina (ARG)               0         0         0        0      41      18
# Armenia (ARM)                 0         0         0        0      11       1
# Australasia (ANZ) [ANZ]       0         0         0        0       2       3
#
#                          Silver.2  Bronze.2  Combined total  \
# ...

# %% [markdown]
# #### Set_index method

# %%
df4 = df4.set_index('Gold')

# %%
df4.head()
# Out:
#       #Summer  Silver  Bronze  Total  #Winter  Gold.1  Silver.1  Bronze.1  \
# Gold
# 0          13       0       2      2        0       0         0         0
# 5          12       2       8     15        3       0         0         0
# 18         23      24      28     70       18       0         0         0
# 1           5       2       9     12        6       0         0         0
# 3           2       4       5     12        0       0         0         0
#
#       Total.1  #Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# Gold
# 0           0      13       0         0         2               2
# 5           0      15       5         2         8              15
# 18          0      41      18        24        28              70
# 1           0      11       1         2         9              12
# 3           0       2       3         4         5              12
#
#                       Country
# Gold
# 0           Afghanistan (AFG)
# 5               Algeria (ALG)
# ...

# %% [markdown]
# ### Resetting the index
# For a dataframe the index can be reset by using the .reset_index method

# %%
df4 = df4.reset_index()
df4.head()
# Out:
#    Gold  #Summer  Silver  Bronze  Total  #Winter  Gold.1  Silver.1  Bronze.1  \
# 0     0       13       0       2      2        0       0         0         0
# 1     5       12       2       8     15        3       0         0         0
# 2    18       23      24      28     70       18       0         0         0
# 3     1        5       2       9     12        6       0         0         0
# 4     3        2       4       5     12        0       0         0         0
#
#    Total.1  #Games  Gold.2  Silver.2  Bronze.2  Combined total  \
# 0        0      13       0         0         2               2
# 1        0      15       5         2         8              15
# 2        0      41      18        24        28              70
# 3        0      11       1         2         9              12
# 4        0       2       3         4         5              12
#
#                    Country
# 0        Afghanistan (AFG)
# 1            Algeria (ALG)
# 2          Argentina (ARG)
# ...

# %% [markdown]
# ### Multi level indexing
# Pandas allows multilevel indexing, this is similar to composite keys in a relational databasae system.
#
# To create a multilevel index we simply call the set index and provide a list of column names that we are interested in.
#
# Pandas will search through these in order finding the distinct data and forming composite indices.

# %%
df5 = pd.read_csv('census.csv')
df5.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %% [markdown]
# #### .unique() operator on the column of the data frame.
# .unique() operator gives all the unique values in that column of dataframe

# %%
df5['SUMLEV'].unique()
# Out:
# array([40, 50], dtype=int64)

# %%
df5 = df5[df5['SUMLEV'] == 50]
df5.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
# 5          57322              57322            57373     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 1          7.242091         -2.915927         -3.012349          2.265971
# ...

# %%
columns_to_keep = ['STNAME',
                   'CTYNAME',
                   'BIRTHS2010',
                   'BIRTHS2011',
                   'BIRTHS2012',
                   'BIRTHS2013',
                   'BIRTHS2014',
                   'BIRTHS2015',
                   'POPESTIMATE2010',
                   'POPESTIMATE2011',
                   'POPESTIMATE2012',
                   'POPESTIMATE2013',
                   'POPESTIMATE2014',
                   'POPESTIMATE2015']

# %%
columns_to_keep
# Out:
# ['STNAME',
#  'CTYNAME',
#  'BIRTHS2010',
#  'BIRTHS2011',
#  'BIRTHS2012',
#  'BIRTHS2013',
#  'BIRTHS2014',
#  'BIRTHS2015',
#  'POPESTIMATE2010',
#  'POPESTIMATE2011',
#  'POPESTIMATE2012',
#  'POPESTIMATE2013',
#  'POPESTIMATE2014',
#  'POPESTIMATE2015']

# %%
df5 = df5[columns_to_keep]
df5.head()
# Out:
#     STNAME         CTYNAME  BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# 1  Alabama  Autauga County         151         636         615         574
# 2  Alabama  Baldwin County         517        2187        2092        2160
# 3  Alabama  Barbour County          70         335         300         283
# 4  Alabama     Bibb County          44         266         245         259
# 5  Alabama   Blount County         183         744         710         646
#
#    BIRTHS2014  BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 1         623         600            54660            55253            55175
# 2        2186        2240           183193           186659           190396
# 3         260         269            27341            27226            27159
# 4         247         253            22861            22733            22642
# 5         618         603            57373            57711            57776
#
# ...

# %%
df5 = df5.set_index(['STNAME','CTYNAME'])
df5.tail(30)
# Out:
#                               BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME    CTYNAME
# Wisconsin Washburn County             36         161         155         152
#           Washington County          350        1348        1320        1296
#           Waukesha County            960        3805        3802        3757
#           Waupaca County             131         492         537         518
#           Waushara County             66         221         236         229
#           Winnebago County           503        1879        1925        1899
#           Wood County                249         895         825         859
# Wyoming   Albany County              104         413         443         410
#           Big Horn County             24         150         132         136
#           Campbell County            208         722         766         732
#           Carbon County               46         200         188         199
# ...

# %%
df5.loc['Washington'].head(5)
# Out:
#                 BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  BIRTHS2014  \
# CTYNAME
# Adams County           145         426         402         411         373
# Asotin County           62         252         229         251         238
# Benton County          656        2555        2603        2522        2572
# Chelan County          269         943         938         924         906
# Clallam County         167         685         656         662         666
#
#                 BIRTHS2015  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# CTYNAME
# Adams County           399            18810            18883            18962
# Asotin County          241            21710            21920            21878
# Benton County         2590           176516           180580           182532
# Chelan County          922            72743            73327            73705
# Clallam County         677            71533            71778            71829
#
# ...

# %% [markdown]
# For a multiindex dataframe the .loc operator can be used with just one argument as show in the above case, but the argument should the 1st one which was used to creat the datframe, in above case it is State name and not the county name
#
# df5.loc['Washington County'].head(5)
# on trying to use .loc on a county name(secondary index) key error is obtained

# %%
df5.loc[[('Washington','Washington County')]]
# Out:
#                               BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME     CTYNAME
# Washington Washington County         NaN         NaN         NaN         NaN
#
#                               BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME     CTYNAME
# Washington Washington County         NaN         NaN              NaN
#
#                               POPESTIMATE2011  POPESTIMATE2012  \
# STNAME     CTYNAME
# Washington Washington County              NaN              NaN
#
#                               POPESTIMATE2013  POPESTIMATE2014  \
# STNAME     CTYNAME
# Washington Washington County              NaN              NaN
#
#                               POPESTIMATE2015
# STNAME     CTYNAME
# Washington Washington County              NaN

# %%
df5.loc[[('Michigan','Washtenaw County'),('Michigan','Wayne')]]
# Out:
#                            BIRTHS2010  BIRTHS2011  BIRTHS2012  BIRTHS2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County       977.0      3826.0      3780.0      3662.0
#          Wayne                    NaN         NaN         NaN         NaN
#
#                            BIRTHS2014  BIRTHS2015  POPESTIMATE2010  \
# STNAME   CTYNAME
# Michigan Washtenaw County      3683.0      3709.0         345563.0
#          Wayne                    NaN         NaN              NaN
#
#                            POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# STNAME   CTYNAME
# Michigan Washtenaw County         349048.0         351213.0         354289.0
#          Wayne                         NaN              NaN              NaN
#
#                            POPESTIMATE2014  POPESTIMATE2015
# STNAME   CTYNAME
# Michigan Washtenaw County         357029.0         358880.0
#          Wayne                         NaN              NaN

# %%
df6 = pd.read_csv('log.csv')
df6
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974454  cheryl     intro.html                  6    NaN     NaN
# 2   1469974544  cheryl     intro.html                  9    NaN     NaN
# 3   1469974574  cheryl     intro.html                 10    NaN     NaN
# 4   1469977514     bob     intro.html                  1    NaN     NaN
# 5   1469977544     bob     intro.html                  1    NaN     NaN
# 6   1469977574     bob     intro.html                  1    NaN     NaN
# 7   1469977604     bob     intro.html                  1    NaN     NaN
# 8   1469974604  cheryl     intro.html                 11    NaN     NaN
# 9   1469974694  cheryl     intro.html                 14    NaN     NaN
# 10  1469974724  cheryl     intro.html                 15    NaN     NaN
# 11  1469974454     sue  advanced.html                 24    NaN     NaN
# ...

# %%
df6 = df6.set_index('time')
df6 = df6.sort_index()
df6
# Out:
#               user          video  playback position paused  volume
# time
# 1469974424  cheryl     intro.html                  5  False    10.0
# 1469974424     sue  advanced.html                 23  False    10.0
# 1469974454  cheryl     intro.html                  6    NaN     NaN
# 1469974454     sue  advanced.html                 24    NaN     NaN
# 1469974484  cheryl     intro.html                  7    NaN     NaN
# 1469974514  cheryl     intro.html                  8    NaN     NaN
# 1469974524     sue  advanced.html                 25    NaN     NaN
# 1469974544  cheryl     intro.html                  9    NaN     NaN
# 1469974554     sue  advanced.html                 26    NaN     NaN
# 1469974574  cheryl     intro.html                 10    NaN     NaN
# 1469974604  cheryl     intro.html                 11    NaN     NaN
# 1469974624     sue  advanced.html                 27    NaN     NaN
# 1469974634  cheryl     intro.html                 12    NaN     NaN
# ...

# %%
df6 = df6.reset_index()

# %%
df6
# Out:
#           time    user          video  playback position paused  volume
# 0   1469974424  cheryl     intro.html                  5  False    10.0
# 1   1469974424     sue  advanced.html                 23  False    10.0
# 2   1469974454  cheryl     intro.html                  6    NaN     NaN
# 3   1469974454     sue  advanced.html                 24    NaN     NaN
# 4   1469974484  cheryl     intro.html                  7    NaN     NaN
# 5   1469974514  cheryl     intro.html                  8    NaN     NaN
# 6   1469974524     sue  advanced.html                 25    NaN     NaN
# 7   1469974544  cheryl     intro.html                  9    NaN     NaN
# 8   1469974554     sue  advanced.html                 26    NaN     NaN
# 9   1469974574  cheryl     intro.html                 10    NaN     NaN
# 10  1469974604  cheryl     intro.html                 11    NaN     NaN
# 11  1469974624     sue  advanced.html                 27    NaN     NaN
# ...

# %%
df6 = df6.set_index(['time','user'])
df6
# Out:
#                            video  playback position paused  volume
# time       user
# 1469974424 cheryl     intro.html                  5  False    10.0
#            sue     advanced.html                 23  False    10.0
# 1469974454 cheryl     intro.html                  6    NaN     NaN
#            sue     advanced.html                 24    NaN     NaN
# 1469974484 cheryl     intro.html                  7    NaN     NaN
# 1469974514 cheryl     intro.html                  8    NaN     NaN
# 1469974524 sue     advanced.html                 25    NaN     NaN
# 1469974544 cheryl     intro.html                  9    NaN     NaN
# 1469974554 sue     advanced.html                 26    NaN     NaN
# 1469974574 cheryl     intro.html                 10    NaN     NaN
# 1469974604 cheryl     intro.html                 11    NaN     NaN
# 1469974624 sue     advanced.html                 27    NaN     NaN
# 1469974634 cheryl     intro.html                 12    NaN     NaN
# ...

# %% [markdown]
# na_filter can be used to turn off the white space filtering, if white space is an actual value of interest

# %%
df6.fillna?

# %% [markdown]
# #### .fillna() method.
# df6.fillna(value=None, method=None, axis=None, inplace=False, limit=None, downcast=None, **kwargs)
#
# example:
#
# "value" parameter takes a scalar value and changes all the Nan values in the df to this scalar value.
#
# "Method" paramneter has two common parameters as ffill and bfill
#
# --> ffill is for forward filling and it updates an na value at a particular cell with the value from the previous row.It's is important to note that your data needs to be sorted in order for this to have effect that you might want.
#
# while filling missing data in a dataframe we need not have to fill all the values at once, there is a option to fill the data either column wise or a couple of cells.By making use ffilling or bfilling.

# %% [markdown]
# More recently pandas team introduced a method of filling missing values with a series which is same length as your dataframe.
#
# While calculating things like mean, sum etc on data frame it has to be kept in mind that pandas ignores the missing values during calculation.

# %% [markdown]
# ## Merging Dataframes

# %%
import pandas as pd

df = pd.DataFrame([{'Name': 'Chris', 'Item Purchased': 'Sponge', 'Cost': 22.50},
                   {'Name': 'Kevyn', 'Item Purchased': 'Kitty Litter', 'Cost': 2.50},
                   {'Name': 'Filip', 'Item Purchased': 'Spoon', 'Cost': 5.00}],
                  index=['Store 1', 'Store 1', 'Store 2'])
df
# Out:
#          Cost Item Purchased   Name
# Store 1  22.5         Sponge  Chris
# Store 1   2.5   Kitty Litter  Kevyn
# Store 2   5.0          Spoon  Filip

# %%
df['Date'] = ['December 1', 'January 1', 'mid-May']
df
# Out:
#          Cost Item Purchased   Name        Date
# Store 1  22.5         Sponge  Chris  December 1
# Store 1   2.5   Kitty Litter  Kevyn   January 1
# Store 2   5.0          Spoon  Filip     mid-May

# %%
df['Delivered'] = True
df
# Out:
#          Cost Item Purchased   Name        Date Delivered
# Store 1  22.5         Sponge  Chris  December 1      True
# Store 1   2.5   Kitty Litter  Kevyn   January 1      True
# Store 2   5.0          Spoon  Filip     mid-May      True

# %%
df['Feedback'] = ['Positive', None, 'Negative']
df
# Out:
#          Cost Item Purchased   Name        Date Delivered  Feedback
# Store 1  22.5         Sponge  Chris  December 1      True  Positive
# Store 1   2.5   Kitty Litter  Kevyn   January 1      True      None
# Store 2   5.0          Spoon  Filip     mid-May      True  Negative

# %%
adf = df.reset_index()
adf['Date'] = pd.Series({0: 'December 1', 2: 'mid-May'})
adf
# Out:
#      index  Cost Item Purchased   Name        Date Delivered  Feedback
# 0  Store 1  22.5         Sponge  Chris  December 1      True  Positive
# 1  Store 1   2.5   Kitty Litter  Kevyn         NaN      True      None
# 2  Store 2   5.0          Spoon  Filip     mid-May      True  Negative

# %% [markdown]
# Since the index is reset now the index is starting from 0 and goes upto 2,
#
# Here we are passing another series in the form of dictonary for the column 'Date' with just two key+values pair, now the corresponding keys act as the index of the dataframe and store Nan for the remaining cell which doesn't have it's row in series.

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])
staff_df
# Out:
#     Name            Role
# 0  Kelly  Director of HR
# 1  Sally  Course liasion
# 2  James          Grader

# %%
staff_df = staff_df.set_index('Name')

# %%
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader

# %%
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])
student_df = student_df.set_index('Name')
print(staff_df.head())
print()
print(student_df.head())
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader
#
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
pd.merge(staff_df, student_df, how='outer', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %% [markdown]
# In case of merge the ouput dataframe columns are in the order in which the input dataframes are given, i.e. in the above example since 'name' is taken as the index the remaining columns are 'Role' in "staff_df" and 'School' in "student_df" and since the order inside the merge method is staff_df, school_df 'Role' column will come 1st and then 'School'.

# %%
pd.merge(student_df, staff_df, how='outer', left_index=True, right_index=True)
# Out:
#             School            Role
# Name
# James     Business          Grader
# Kelly          NaN  Director of HR
# Mike           Law             NaN
# Sally  Engineering  Course liasion

# %%
pd.merge(staff_df,student_df,how='inner', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Sally  Course liasion  Engineering

# %% [markdown]
# ####  Venn Diagrams
# Outer join is Union.
#
# Inner join is Intersection.
#
# Left join and right join will have the elements that are shared amoung two sets along with the elements that are exclusive to a set also.
#
# On merging two data frames then pandas automatically fills Nan for the cells which doesn't have a value.

# %%
pd.merge(staff_df, student_df, how='left', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(student_df,staff_df, how='left', left_index=True, right_index=True)
# Out:
#             School            Role
# Name
# James     Business          Grader
# Mike           Law             NaN
# Sally  Engineering  Course liasion

# %%
pd.merge(staff_df, student_df, how='right', left_index=True, right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
pd.merge(student_df,staff_df, how='right', left_index=True, right_index=True)
# Out:
#             School            Role
# Name
# Kelly          NaN  Director of HR
# Sally  Engineering  Course liasion
# James     Business          Grader

# %% [markdown]
# Till now only index are used to merge two dataframes using index but it is also possible to join two datdframes using the column names.

# %%
staff_df = staff_df.reset_index()
student_df = student_df.reset_index()
pd.merge(student_df, staff_df, how='left', left_on='Name', right_on='Name')
# Out:
#     Name       School            Role
# 0  James     Business          Grader
# 1   Mike          Law             NaN
# 2  Sally  Engineering  Course liasion

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 'Location': 'State Street'},
                         {'Name': 'Sally', 'Role': 'Course liasion', 'Location': 'Washington Avenue'},
                         {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Avenue'}])
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 'Location': '1024 Billiard Avenue'},
                           {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House #22'},
                           {'Name': 'Sally', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])
pd.merge(staff_df, student_df, how='left', left_on='Name', right_on='Name')
# Out:
#           Location_x   Name            Role            Location_y       School
# 0       State Street  Kelly  Director of HR                   NaN          NaN
# 1  Washington Avenue  Sally  Course liasion   512 Wilson Crescent  Engineering
# 2  Washington Avenue  James          Grader  1024 Billiard Avenue     Business

# %% [markdown]
# Merging fo two Dataframes doesn't affect the original Dataframe

# %% [markdown]
# On merging datafrmaes based on columns we get _X and _y for the columns that are common in the two dataframes.
#
# In the above example 'location' is common column name in both the dataframes hence  it has a suffix _x and _y to differentiate which dataframe it belongs to.
#
# In case of a left join the sufix _x will be added to 1st dataframe that was passed on to merge method.

# %%
products = pd.DataFrame([{'Product ID':4109,'Price':5.0,'Product':'Sushi Roll'},
                         {'Product ID':1412,'Price':0.5,'Product':'Egg'},
                         {'Product ID':8931,'Price':1.5,'Product':'Bagel'}])
products
# Out:
#    Price     Product  Product ID
# 0    5.0  Sushi Roll        4109
# 1    0.5         Egg        1412
# 2    1.5       Bagel        8931

# %%
invoices = pd.DataFrame([{'Product ID':4109,'Customer':'Ali','Quantity':1},
                         {'Product ID':1412,'Customer':'Eric','Quantity':12},
                         {'Product ID':8931,'Customer':'Ande','Quantity':6},
                         {'Product ID':4109,'Customer':'Sam','Quantity':2}])
invoices
# Out:
#   Customer  Product ID  Quantity
# 0      Ali        4109         1
# 1     Eric        1412        12
# 2     Ande        8931         6
# 3      Sam        4109         2

# %%
answer = pd.merge(products, invoices, how = 'left', left_on = 'Product ID',right_on = 'Product ID')
answer
# Out:
#    Price     Product  Product ID Customer  Quantity
# 0    5.0  Sushi Roll        4109      Ali         1
# 1    5.0  Sushi Roll        4109      Sam         2
# 2    0.5         Egg        1412     Eric        12
# 3    1.5       Bagel        8931     Ande         6

# %%
answer['total'] = answer['Price'] * answer['Quantity']
answer
# Out:
#    Price     Product  Product ID Customer  Quantity  total
# 0    5.0  Sushi Roll        4109      Ali         1    5.0
# 1    5.0  Sushi Roll        4109      Sam         2   10.0
# 2    0.5         Egg        1412     Eric        12    6.0
# 3    1.5       Bagel        8931     Ande         6    9.0

# %%
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 'Role': 'Director of HR'},
                         {'First Name': 'Sally', 'Last Name': 'Brooks', 'Role': 'Course liasion'},
                         {'First Name': 'James', 'Last Name': 'Wilde', 'Role': 'Grader'}])
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 'School': 'Business'},
                           {'First Name': 'Mike', 'Last Name': 'Smith', 'School': 'Law'},
                           {'First Name': 'Sally', 'Last Name': 'Brooks', 'School': 'Engineering'}])
staff_df
student_df
pd.merge(staff_df, student_df, how='inner', left_on=['First Name','Last Name'], right_on=['First Name','Last Name'])
# Out:
#   First Name Last Name            Role       School
# 0      Sally    Brooks  Course liasion  Engineering

# %% [markdown]
# While merging two datframes it is possible to merge them based on two or more column names, as shown in the above case.
#
# The result has just sally Brooks in it because the for james the last name is different and on doing intersection while keeping first and last name in consideration only sally qualifies.

# %% [markdown]
# ## Idiomatic Pandas: Making Code Pandorable

# %% [markdown]
# Chaining is a bad paatice in coding of Pandas and if you see "][" then you are using chaining

# %%
import pandas as pd
df = pd.read_csv('census.csv')
df.head(5)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
# %%timeit -n 100
(df.where(df['SUMLEV']==50)
    .dropna()
    .set_index(['STNAME','CTYNAME'])
    .rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'}))
# Out:
# 100 loops, best of 3: 22.7 ms per loop

# %%
import pandas as pd
df1 = pd.read_csv('census.csv')

# %%
# %%timeit -n 100
df2 = df1[df1['SUMLEV']==50]
df2.set_index(['STNAME','CTYNAME'], inplace=True)
df2.rename(columns={'ESTIMATESBASE2010': 'Estimates Base 2010'})
# Out:
# 100 loops, best of 3: 6.47 ms per loop

# %% [markdown]
# From the above two timeit examples  it can be seen that pandaroable code need not take lesser time for execution.

# %% [markdown]
# A dataframe with only certain number of coloumns is to be created by using another dataframe then we can make use of indexing i.e. big brackets.
# The returned dataframe will have same index as the original but will have only those columns.

# %%
df1.head(5)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df1[['CENSUS2010POP','ESTIMATESBASE2010']]
# Out:
#       CENSUS2010POP  ESTIMATESBASE2010
# 0           4779736            4780127
# 1             54571              54571
# 2            182265             182265
# 3             27457              27457
# 4             22915              22919
# 5             57322              57322
# 6             10914              10915
# 7             20947              20946
# 8            118572             118586
# 9             34215              34170
# 10            25989              25986
# 11            43643              43631
# 12            13859              13858
# 13            25833              25840
# 14            13932              13932
# 15            14972              14972
# 16            49948              49948
# 17            54428              54428
# 18            13228              13228
# 19            11539              11758
# 20            37765              37765
# 21            13906              13906
# 22            80406              80410
# ...

# %%
import numpy as np
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    return pd.Series({'min': np.min(data), 'max': np.max(data)})

# %% [markdown]
# While using a apply we are not passing any arguments to the function coz i think what ever is before '.apply' will go as the argument to the function.
#
# so in the above case on executing .apply() method df1 has become row inside the min_max function and data is nothing but sub set dataframe of df1 which has only those columns mentioned inside function.
#
# .apply method takes two arguments
#
# 1st on : is a function or a lambda
#
# 2nd on: is the axis

# %%
df1.apply(min_max, axis=1)
# Out:
#           max      min
# 0     4858979  4785161
# 1       55347    54660
# 2      203709   183193
# 3       27341    26489
# 4       22861    22512
# 5       57776    57373
# 6       10887    10606
# 7       20944    20154
# 8      118437   115620
# 9       34153    33993
# 10      26084    25859
# 11      43943    43665
# 12      13841    13170
# 13      25767    24675
# 14      13880    13456
# 15      15072    14921
# 16      51211    50177
# 17      54514    54354
# 18      13208    12662
# 19      11758    10724
# 20      38060    37796
# 21      13963    13853
# 22      82005    80374
# 23      50358    49501
# 24      43803    41131
# 25      71387    70869
# 26      81468    79465
# 27      38309    37784
# 28     104442   103057
# 29      17231    16759
# ...       ...      ...
# 3163   133674   131967
# 3164   396488   390076
# 3165    52422    51945
# 3166    24581    24033
# 3167   169639   167059
# 3168    74807    73435
# 3169   586107   564516
# 3170    37956    36428
# ...

# %%
import numpy as np
def min_max(row):
    data = row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    row['max'] = np.max(data)
    row['min'] = np.min(data)
    return row
df1.apply(min_max, axis=1)
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 0         40       3         6      1       0    Alabama             Alabama
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# ...

# %%
rows = ['POPESTIMATE2010',
        'POPESTIMATE2011',
        'POPESTIMATE2012',
        'POPESTIMATE2013',
        'POPESTIMATE2014',
        'POPESTIMATE2015']
df1.apply(lambda x: np.max(x[rows]), axis=1)
# Out:
# 0       4858979
# 1         55347
# 2        203709
# 3         27341
# 4         22861
# 5         57776
# 6         10887
# 7         20944
# 8        118437
# 9         34153
# 10        26084
# 11        43943
# 12        13841
# 13        25767
# 14        13880
# 15        15072
# 16        51211
# 17        54514
# 18        13208
# 19        11758
# 20        38060
# 21        13963
# 22        82005
# 23        50358
# 24        43803
# 25        71387
# 26        81468
# 27        38309
# 28       104442
# 29        17231
#          ...
# 3163     133674
# 3164     396488
# 3165      52422
# 3166      24581
# 3167     169639
# 3168      74807
# 3169     586107
# 3170      37956
# 3171      12022
# 3172      49220
# 3173      15856
# 3174      14343
# 3175       7444
# 3176      41129
# 3177      13666
# 3178       4846
# 3179       8636
# 3180      97121
# 3181      18722
# 3182      82178
# 3183       2548
# 3184      29237
# 3185       8812
# 3186      30020
# ...

# %% [markdown]
# ## Group By

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# 11        50       3         6      1      21    Alabama      Chilton County
# ...

# %%
df.where(df['STNAME']=='Alabama')
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME           CTYNAME  \
# 1       50.0     3.0       6.0    1.0     1.0  Alabama    Autauga County
# 2       50.0     3.0       6.0    1.0     3.0  Alabama    Baldwin County
# 3       50.0     3.0       6.0    1.0     5.0  Alabama    Barbour County
# 4       50.0     3.0       6.0    1.0     7.0  Alabama       Bibb County
# 5       50.0     3.0       6.0    1.0     9.0  Alabama     Blount County
# 6       50.0     3.0       6.0    1.0    11.0  Alabama    Bullock County
# 7       50.0     3.0       6.0    1.0    13.0  Alabama     Butler County
# 8       50.0     3.0       6.0    1.0    15.0  Alabama    Calhoun County
# 9       50.0     3.0       6.0    1.0    17.0  Alabama   Chambers County
# 10      50.0     3.0       6.0    1.0    19.0  Alabama   Cherokee County
# 11      50.0     3.0       6.0    1.0    21.0  Alabama    Chilton County
# 12      50.0     3.0       6.0    1.0    23.0  Alabama    Choctaw County
# ...

# %% [markdown]
# This query returns a dataframe that has all the cells as the original df but only show those rows will have value in which the state name is Alabama

# %%
df.where(df['STNAME']=='Alabama').dropna()
# Out:
#     SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 1     50.0     3.0       6.0    1.0     1.0  Alabama     Autauga County
# 2     50.0     3.0       6.0    1.0     3.0  Alabama     Baldwin County
# 3     50.0     3.0       6.0    1.0     5.0  Alabama     Barbour County
# 4     50.0     3.0       6.0    1.0     7.0  Alabama        Bibb County
# 5     50.0     3.0       6.0    1.0     9.0  Alabama      Blount County
# 6     50.0     3.0       6.0    1.0    11.0  Alabama     Bullock County
# 7     50.0     3.0       6.0    1.0    13.0  Alabama      Butler County
# 8     50.0     3.0       6.0    1.0    15.0  Alabama     Calhoun County
# 9     50.0     3.0       6.0    1.0    17.0  Alabama    Chambers County
# 10    50.0     3.0       6.0    1.0    19.0  Alabama    Cherokee County
# 11    50.0     3.0       6.0    1.0    21.0  Alabama     Chilton County
# 12    50.0     3.0       6.0    1.0    23.0  Alabama     Choctaw County
# ...

# %% [markdown]
# The new dataframe has only those rows in which the state name is Alabama. i.e. in other words all other rows which did not ful fill the statename == 'Alabama' had Nan values in them and now they have been removed from dataframe

# %%
df.where(df['STNAME']=='Alabama').dropna()['CENSUS2010POP']
# Out:
# 1      54571.0
# 2     182265.0
# 3      27457.0
# 4      22915.0
# 5      57322.0
# 6      10914.0
# 7      20947.0
# 8     118572.0
# 9      34215.0
# 10     25989.0
# 11     43643.0
# 12     13859.0
# 13     25833.0
# 14     13932.0
# 15     14972.0
# 16     49948.0
# 17     54428.0
# 18     13228.0
# 19     11539.0
# 20     37765.0
# 21     13906.0
# 22     80406.0
# 23     50251.0
# 24     43820.0
# 25     71109.0
# 26     79303.0
# 27     38319.0
# 28    104430.0
# 29     17241.0
# 30     31704.0
#         ...
# 38     14564.0
# 39     92709.0
# 40     34339.0
# 41    140247.0
# 42     82782.0
# 43     11299.0
# 44     21452.0
# 45    334811.0
# 46     21027.0
# 47     30776.0
# 48     93019.0
# 49    412992.0
# 50     23068.0
# 51    229363.0
# 52    119490.0
# 53     10591.0
# 54     19746.0
# 55     32899.0
# 56     22913.0
# 57     52947.0
# 58     83593.0
# 59    195085.0
# 60     13763.0
# 61     82291.0
# 62     41616.0
# 63    194656.0
# 64     67023.0
# 65     17581.0
# ...

# %% [markdown]
# Series returned above has all the counties which  has the state name as 'Alabama'

# %%
a = np.average(df.where(df['STNAME']=='Alabama').dropna()['CENSUS2010POP'])
a
# Out:
# 71339.343283582086

# %% [markdown]
# Here the avarage population of all the counties of state alabama is calculated

# %%
df['STNAME']
# Out:
# 1         Alabama
# 2         Alabama
# 3         Alabama
# 4         Alabama
# 5         Alabama
# 6         Alabama
# 7         Alabama
# 8         Alabama
# 9         Alabama
# 10        Alabama
# 11        Alabama
# 12        Alabama
# 13        Alabama
# 14        Alabama
# 15        Alabama
# 16        Alabama
# 17        Alabama
# 18        Alabama
# 19        Alabama
# 20        Alabama
# 21        Alabama
# 22        Alabama
# 23        Alabama
# 24        Alabama
# 25        Alabama
# 26        Alabama
# 27        Alabama
# 28        Alabama
# 29        Alabama
# 30        Alabama
#           ...
# 3162    Wisconsin
# 3163    Wisconsin
# 3164    Wisconsin
# 3165    Wisconsin
# 3166    Wisconsin
# 3167    Wisconsin
# 3168    Wisconsin
# 3170      Wyoming
# 3171      Wyoming
# 3172      Wyoming
# 3173      Wyoming
# 3174      Wyoming
# 3175      Wyoming
# 3176      Wyoming
# 3177      Wyoming
# 3178      Wyoming
# 3179      Wyoming
# 3180      Wyoming
# 3181      Wyoming
# ...

# %%
for state in df['STNAME'].unique():
    avg = np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    print('Counties in state ' + state + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.3432836
# Counties in state Alaska have an average population of 24490.7241379
# Counties in state Arizona have an average population of 426134.466667
# Counties in state Arkansas have an average population of 38878.9066667
# Counties in state California have an average population of 642309.586207
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.567164
# Counties in state Georgia have an average population of 60928.6352201
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.8636364
# ...

# %% [markdown]
# .where and df[df[]] can be used as an alternative to one other

# %%
(df[df['STNAME'] == 'Alabama'].dropna()['CENSUS2010POP'])
# Out:
# 1      54571
# 2     182265
# 3      27457
# 4      22915
# 5      57322
# 6      10914
# 7      20947
# 8     118572
# 9      34215
# 10     25989
# 11     43643
# 12     13859
# 13     25833
# 14     13932
# 15     14972
# 16     49948
# 17     54428
# 18     13228
# 19     11539
# 20     37765
# 21     13906
# 22     80406
# 23     50251
# 24     43820
# 25     71109
# 26     79303
# 27     38319
# 28    104430
# 29     17241
# 30     31704
#        ...
# 38     14564
# 39     92709
# 40     34339
# 41    140247
# 42     82782
# 43     11299
# 44     21452
# 45    334811
# 46     21027
# 47     30776
# 48     93019
# 49    412992
# 50     23068
# 51    229363
# 52    119490
# 53     10591
# 54     19746
# 55     32899
# 56     22913
# 57     52947
# 58     83593
# 59    195085
# 60     13763
# 61     82291
# 62     41616
# 63    194656
# 64     67023
# 65     17581
# 66     11670
# 67     24484
# Name: CENSUS2010POP, dtype: int64

# %%
# %%timeit -n 10
for state in df['STNAME'].unique():
    avg = np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    print('Counties in state ' + state + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.3432836
# Counties in state Alaska have an average population of 24490.7241379
# Counties in state Arizona have an average population of 426134.466667
# Counties in state Arkansas have an average population of 38878.9066667
# Counties in state California have an average population of 642309.586207
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.567164
# Counties in state Georgia have an average population of 60928.6352201
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.8636364
# ...

# %%
df.groupby('STNAME')

# %%
df.head(5)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
# 5          57322              57322            57373     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 1          7.242091         -2.915927         -3.012349          2.265971
# ...

# %%
df = df.set_index('STNAME')

# %%
def fun(item):
    #print(item)
    if item[0]<'M':
        return 0
    if item[0]<'Q':
        return 1
    return 2

for group, frame in df.groupby(fun):
    print('There are ' + str(len(frame)) + ' records in group ' + str(group) + ' for processing.')
# Out:
# There are 1177 records in group 0 for processing.
# There are 1134 records in group 1 for processing.
# There are 831 records in group 2 for processing.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('census.csv')
df.head(5)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
df = df.set_index('STNAME')
def fun(item):
    if item[0]<'M':
        return 0
    if item[0]<'Q':
        return 1
    return 2

for group, frame in df.groupby(fun):
    print('There are ' + str(len(frame)) + ' records in group ' + str(group) + ' for processing.')
# Out:
# There are 1196 records in group 0 for processing.
# There are 1154 records in group 1 for processing.
# There are 843 records in group 2 for processing.

# %% [markdown]
# In case of the above example also we are passing a function named 'fun' as the argument for the group by method and the index of the datatframe becomes the argument for the defined function i.e. item has all the state names

# %% [markdown]
# This method of grouping is used to divide the dataframe into parts

# %%
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# 11        50       3         6      1      21    Alabama      Chilton County
# ...

# %%
df.groupby('STNAME').agg({'CENSUS2010POP': np.average})
# Out:
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# Kansas                 27172.552381
# Kentucky               36161.391667
# Louisiana              70833.937500
# Maine                  83022.562500
# Maryland              240564.666667
# Massachusetts         467687.785714
# Michigan              119080.000000
# Minnesota              60964.655172
# Mississippi            36186.548780
# ...

# %% [markdown]
# .agg stands for aggregate and it is a method which takes a mathmatical operation to be performed on the argument of group by
# or
#
# dictionary as the argument, in this dictionary column names on which you want to perform certain operation is the key and the corresponding value is the mathematical operation.

# %%
print(df.groupby('CENSUS2010POP').agg(sum))
# Out:
#                SUMLEV  REGION  DIVISION  STATE  COUNTY  ESTIMATESBASE2010  \
# CENSUS2010POP
# 82                 50       3         7     48     301                 82
# 90                 50       4         9     15       5                 90
# 286                50       3         7     48     269                286
# 416                50       3         7     48     261                416
# 460                50       2         4     31       5                460
# 478                50       2         4     31       9                478
# 494                50       4         8     30      69                494
# 539                50       2         4     31     117                539
# 614                50       2         4     31      75                614
# 632                50       2         4     31     115                628
# 641                50       3         7     48      33                641
# ...

# %% [markdown]
# The above example is just to show that the .agg method can also take just a mathematical operation as it's argument and there is  no need of passing a dictionary as it's arguments.

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY     STNAME             CTYNAME  \
# 1         50       3         6      1       1    Alabama      Autauga County
# 2         50       3         6      1       3    Alabama      Baldwin County
# 3         50       3         6      1       5    Alabama      Barbour County
# 4         50       3         6      1       7    Alabama         Bibb County
# 5         50       3         6      1       9    Alabama       Blount County
# 6         50       3         6      1      11    Alabama      Bullock County
# 7         50       3         6      1      13    Alabama       Butler County
# 8         50       3         6      1      15    Alabama      Calhoun County
# 9         50       3         6      1      17    Alabama     Chambers County
# 10        50       3         6      1      19    Alabama     Cherokee County
# 11        50       3         6      1      21    Alabama      Chilton County
# ...

# %%
df.groupby('STNAME')['CENSUS2010POP','ESTIMATESBASE2010'].agg(sum)
# Out:
#                       CENSUS2010POP  ESTIMATESBASE2010
# STNAME
# Alabama                     4779736            4780127
# Alaska                       710231             710249
# Arizona                     6392017            6392307
# Arkansas                    2915918            2915958
# California                 37253956           37254503
# Colorado                    5029196            5029324
# Connecticut                 3574097            3574118
# Delaware                     897934             897936
# District of Columbia         601723             601767
# Florida                    18801310           18804623
# Georgia                     9687653            9688681
# Hawaii                      1360301            1360301
# Idaho                       1567582            1567652
# Illinois                   12830632           12831549
# Indiana                     6483802            6484229
# Iowa                        3046355            3046869
# ...

# %% [markdown]
# The way to use groupby method is as follows,
#
# Give the name of the field based on which you need to group the cells of the dataframe and then a list of columns which you want to consider for performing the mathematical operation,
#
# df.groupby('STNAME')['CENSUS2010POP','ESTIMATESBASE2010'].agg(sum)
#
# use .agg method to give the mathematical operation that you want to perform on those columns which are grouped by a certain criteria
# now since there is no mentioning of a new column name in the above code the new df will have sum of all the counties against the respective state under the two columns.

# %%
print(type(df.groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']))
print(type(df.groupby(level=0)['POPESTIMATE2010']))
# Out:
# <class 'pandas.core.groupby.DataFrameGroupBy'>
# <class 'pandas.core.groupby.SeriesGroupBy'>

# %%
(df.set_index('STNAME').groupby(level=0)['CENSUS2010POP']
    .agg({'avg': np.average, 'sum': np.sum}))
# Out:
#                            sum            avg
# STNAME
# Alabama                4779736   71339.343284
# Alaska                  710231   24490.724138
# Arizona                6392017  426134.466667
# Arkansas               2915918   38878.906667
# California            37253956  642309.586207
# Colorado               5029196   78581.187500
# Connecticut            3574097  446762.125000
# Delaware                897934  299311.333333
# District of Columbia    601723  601723.000000
# Florida               18801310  280616.567164
# Georgia                9687653   60928.635220
# Hawaii                 1360301  272060.200000
# Idaho                  1567582   35626.863636
# Illinois              12830632  125790.509804
# Indiana                6483802   70476.108696
# Iowa                   3046355   30771.262626
# Kansas                 2853118   27172.552381
# Kentucky               4339367   36161.391667
# Louisiana              4533372   70833.937500
# ...

# %% [markdown]
# Group by method has an argument called level, which is set to 0 in the above example and level 0 means that it has to groupby based on the index of the datatframe
# hence the code
#
# (df.set_index('STNAME').groupby(level=0)['CENSUS2010POP']
#     .agg({'avg': np.average, 'sum': np.sum}))
#
# groups the new dataframe as per the index and considers only one column 'CENSUS2010POP' in the new dataframe
#
# using the .agg method two more columns are created in the Df which gives the average and sum of all the counties for each state for the column 'CENSUS2010POP'
#
# The purpose of using () at the start and end of the code is coz in python a line can exist on a number of lines if enclosed inside a pair of ()

# %%
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']
    .agg({'avg': np.average, 'sum': np.sum}))
# Out:
#                                  sum                             avg  \
#                      POPESTIMATE2010 POPESTIMATE2011 POPESTIMATE2010
# STNAME
# Alabama                      4785161         4801108    71420.313433
# Alaska                        714021          722720    24621.413793
# Arizona                      6408208         6468732   427213.866667
# Arkansas                     2922394         2938538    38965.253333
# California                  37334079        37700034   643691.017241
# Colorado                     5048254         5119480    78878.968750
# Connecticut                  3579717         3589759   447464.625000
# Delaware                      899791          907916   299930.333333
# District of Columbia          605126          620472   605126.000000
# Florida                     18849890        19105533   281341.641791
# Georgia                      9713454         9812280    61090.905660
# ...

# %% [markdown]
# (df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']
#     .agg({'avg': np.average, 'sum': np.sum}))
#
# Here groupping is done based on the Index 'STNAME' coz level = 0
#
# The columns under consideration for are 'POPESTIMATE2010','POPESTIMATE2011'
#
# sum and average of each state is to calculated using groupby

# %%
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']
    .agg({'POPESTIMATE2010': np.average, 'POPESTIMATE2011': np.sum}))
# Out:
#                       POPESTIMATE2010  POPESTIMATE2011
# STNAME
# Alabama                  71420.313433          4801108
# Alaska                   24621.413793           722720
# Arizona                 427213.866667          6468732
# Arkansas                 38965.253333          2938538
# California              643691.017241         37700034
# Colorado                 78878.968750          5119480
# Connecticut             447464.625000          3589759
# Delaware                299930.333333           907916
# District of Columbia    605126.000000           620472
# Florida                 281341.641791         19105533
# Georgia                  61090.905660          9812280
# Hawaii                  272796.000000          1378227
# Idaho                    35704.227273          1584134
# Illinois                125894.598039         12861882
# Indiana                  70549.891304          6516845
# Iowa                     30815.090909          3065389
# ...

# %% [markdown]
# (df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']
#     .agg({'POPESTIMATE2010': np.average, 'POPESTIMATE2011': np.sum}))
#
# Here the arguments of .agg method is a dictionary in which the keys are of same name as the columns considered for the operation, hence the returned Dataframe will have two columns with the same name as shown above

# %% [markdown]
# ## Scales

# %% [markdown]
# Generally in DataScience we make use of 4 scales
#
# Ratio Scale: Units are equally spaced and mathematical operations such as +/- are all valid
#
#     Ex: Height and weight
#
# Interval Scale: Units are equally spaced, but there is no true Zero.
#
#     Ex: Temperature and angle measured in degrees
#     here temperature 0 doen't mean the absence of temperature and similarly 0 degree don't mean no angle.
#
# Ordinal Scale: This scale is ordered but the units are not equally spaced.
#
#     Ex: Grades in a college, the difference between an A grade and B grade is 15 while the difference between B grade               and c is 10
#
# Nominal Scale: In this scale the units are not order and dont have equal interval between them.
#
#     Ex: Tick boxes in a survey form asking for Gender, here the intension is to capture the data the order of Male or                 Female is irrespective

# %%
df = pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
                  index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'])
df.rename(columns={0: 'Grades'}, inplace=True)
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df['Grades'].astype('category').head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %% [markdown]
# In pandas there is a datatype called as category which converts a given column to category using the astype function.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, excellent to poor
# Data columns (total 1 columns):
# Grades    11 non-null object
# dtypes: object(1)
# memory usage: 88.0+ bytes

# %% [markdown]
# If you want the data frame to be order in a logical sequence on the category column, then use the below code with ordered = True

# %%
grades = df['Grades'].astype('category',
                             categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
                             ordered=True)
grades.head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
grades > 'C'
# Out:
# excellent     True
# excellent     True
# excellent     True
# good          True
# good          True
# good          True
# ok            True
# ok           False
# ok           False
# poor         False
# poor         False
# Name: Grades, dtype: bool

# %% [markdown]
# now the column 'Grade' of the df is ordered hence it can be considered as a Ordinal scaled data and therefore boolean masking can be performed on the column

# %%
s = pd.Series(['Low', 'Low', 'High', 'Medium', 'Low', 'High', 'Low'])
s
# Out:
# 0       Low
# 1       Low
# 2      High
# 3    Medium
# 4       Low
# 5      High
# 6       Low
# dtype: object

# %%
# Your code here
s.astype('category', categories = ['Low', 'Medium', 'High'], ordered = True).head(10)
# Out:
# 0       Low
# 1       Low
# 2      High
# 3    Medium
# 4       Low
# 5      High
# 6       Low
# dtype: category
# Categories (3, object): [Low < Medium < High]

# %%
s < 'Medium'
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# dtype: bool

# %% [markdown]
# Variables with a Boolean value are typically dummmy variables and pandas has a built-in function called get_dummies  which will convert the values of a single column into multiple columns of 0's and 1's, indicating the presence of a dummy variable.

# %%
df = pd.read_csv('census.csv')
df = df[df['SUMLEV']==50]
df = df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg({'avg': np.average})
pd.cut(df['avg'],10)
# Out:
# STNAME
# Alabama                  (11706.0871, 75333.413]
# Alaska                   (11706.0871, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                 (11706.0871, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                  (11706.0871, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# Idaho                    (11706.0871, 75333.413]
# Illinois                 (75333.413, 138330.766]
# Indiana                  (11706.0871, 75333.413]
# Iowa                     (11706.0871, 75333.413]
# Kansas                   (11706.0871, 75333.413]
# Kentucky                 (11706.0871, 75333.413]
# Louisiana                (11706.0871, 75333.413]
# ...

# %%
s = pd.Series([168, 180, 175.333, 190, 170, 185, 179, 181, 175, 169, 182, 177, 180, 171])
pd.cut(s,3)
# Out:
# 0     (167.978, 175.333]
# 1     (175.333, 182.667]
# 2     (167.978, 175.333]
# 3         (182.667, 190]
# 4     (167.978, 175.333]
# 5         (182.667, 190]
# 6     (175.333, 182.667]
# 7     (175.333, 182.667]
# 8     (167.978, 175.333]
# 9     (167.978, 175.333]
# 10    (175.333, 182.667]
# 11    (175.333, 182.667]
# 12    (175.333, 182.667]
# 13    (167.978, 175.333]
# dtype: category
# Categories (3, object): [(167.978, 175.333] < (175.333, 182.667] < (182.667, 190]]

# %% [markdown]
# ### Binning
#
# Binning: In case of a series pandas looks into the lowest and the highest value in the series and creates bins for the lowest and highest value, the second argument for .cut method is the number of bins to be created.
#
# The brackets [ and ] means: The number is included, This side of the interval is closed,
# The parenthesis ( and ) means: The number is excluded, This side of the interval is open.
#
# On observing the above output it can be seen that there are three bins and all the values in the series belong to one of the three bins.

# %% [markdown]
# ## Pivot tables

# %%
cars_df = pd.read_csv('cars.csv')

# %%
cars_df.head(5)
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km) RATING  (km)  TIME (h)
# ...

# %%
cars_df.pivot_table(values='(kW)', index='YEAR', columns='Make', aggfunc=np.mean)
# Out:
# Make    BMW  CHEVROLET   FORD   KIA  MITSUBISHI  NISSAN  SMART       TESLA
# YEAR
# 2012    NaN        NaN    NaN   NaN        49.0    80.0    NaN         NaN
# 2013    NaN        NaN  107.0   NaN        49.0    80.0   35.0  280.000000
# 2014    NaN      104.0  107.0   NaN        49.0    80.0   35.0  268.333333
# 2015  125.0      104.0  107.0  81.0        49.0    80.0   35.0  320.666667
# 2016  125.0      104.0  107.0  81.0        49.0    80.0   35.0  409.700000

# %%
cars_df.pivot_table(values=['(kW)','(km)'], index='YEAR', columns='Make', aggfunc=np.mean)
# Out:
#        (kW)                                                              (km)  \
# Make    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART       TESLA    BMW
# YEAR
# 2012    NaN       NaN    NaN   NaN       49.0   80.0   NaN         NaN    NaN
# 2013    NaN       NaN  107.0   NaN       49.0   80.0  35.0  280.000000    NaN
# 2014    NaN     104.0  107.0   NaN       49.0   80.0  35.0  268.333333    NaN
# 2015  125.0     104.0  107.0  81.0       49.0   80.0  35.0  320.666667  130.0
# 2016  125.0     104.0  107.0  81.0       49.0   80.0  35.0  409.700000  130.0
#
#
# Make CHEVROLET   FORD    KIA MITSUBISHI NISSAN  SMART       TESLA
# YEAR
# 2012       NaN    NaN    NaN      100.0  117.0    NaN         NaN
# 2013       NaN  122.0    NaN      100.0  117.0  109.0  352.750000
# 2014     131.0  122.0    NaN      100.0  135.0  109.0  395.666667
# 2015     131.0  122.0  149.0      100.0  135.0  109.0  394.333333
# 2016     131.0  122.0  149.0      100.0  153.5  109.0  409.000000

# %% [markdown]
# import numpy as np
# import pandas as pd
# Bikes.pivot_table(values = ['Price','Rating'], columns = ['Manufacturer','Bike'],aggfunc = np.mean)

# %% [markdown]
# pivot_table take 3 arguments 'values', 'index'  and 'column' and at the end the mathematical operation which is to be performed using the argument aggfunc

# %%
cars_df.pivot_table(values='(kW)', index='YEAR', columns='Make', aggfunc=[np.mean,np.min], margins=True)
# Out:
#        mean                                                             \
# Make    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART       TESLA
# YEAR
# 2012    NaN       NaN    NaN   NaN       49.0   80.0   NaN         NaN
# 2013    NaN       NaN  107.0   NaN       49.0   80.0  35.0  280.000000
# 2014    NaN     104.0  107.0   NaN       49.0   80.0  35.0  268.333333
# 2015  125.0     104.0  107.0  81.0       49.0   80.0  35.0  320.666667
# 2016  125.0     104.0  107.0  81.0       49.0   80.0  35.0  409.700000
# All   125.0     104.0  107.0  81.0       49.0   80.0  35.0  345.478261
#
#                    amin                                                        \
# Make         All    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART  TESLA
# YEAR
# 2012   64.500000    NaN       NaN    NaN   NaN       49.0   80.0   NaN    NaN
# 2013  158.444444    NaN       NaN  107.0   NaN       49.0   80.0  35.0  270.0
# ...

# %% [markdown]
# Here on using the margins = True we get a column called 'All' which has mean and min of all the vaues in that part of the pivot table respectively.
#
# It is possible to pass any function to the aggfun , including those functions that are user defined

# %% [markdown]
# Assignment 3

# %% [markdown]
# ### Question 1 (20%)
# Load the energy data from the file `Energy Indicators.xls`, which is a list of indicators of [energy supply and renewable electricity production](Energy%20Indicators.xls) from the [United Nations](http://unstats.un.org/unsd/environment/excel_file_tables/2013/Energy%20Indicators.xls) for the year 2013, and should be put into a DataFrame with the variable name of **energy**.
#
# Keep in mind that this is an Excel file, and not a comma separated values file. Also, make sure to exclude the footer and header information from the datafile. The first two columns are unneccessary, so you should get rid of them, and you should change the column labels so that the columns are:
#
# `['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']`
#
# Convert `Energy Supply` to gigajoules (there are 1,000,000 gigajoules in a petajoule). For all countries which have missing data (e.g. data with "...") make sure this is reflected as `np.NaN` values.
#
# Rename the following list of countries (for use in later questions):
#
# ```"Republic of Korea": "South Korea",
# "United States of America": "United States",
# "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
# "China, Hong Kong Special Administrative Region": "Hong Kong"```
#
# There are also several countries with numbers and/or parenthesis in their name. Be sure to remove these,
#
# e.g.
#
# `'Bolivia (Plurinational State of)'` should be `'Bolivia'`,
#
# `'Switzerland17'` should be `'Switzerland'`.
#
# <br>
#
# Next, load the GDP data from the file `world_bank.csv`, which is a csv containing countries' GDP from 1960 to 2015 from [World Bank](http://data.worldbank.org/indicator/NY.GDP.MKTP.CD). Call this DataFrame **GDP**.
#
# Make sure to skip the header, and rename the following list of countries:
#
# ```"Korea, Rep.": "South Korea",
# "Iran, Islamic Rep.": "Iran",
# "Hong Kong SAR, China": "Hong Kong"```
#
# <br>
#
# Finally, load the [Sciamgo Journal and Country Rank data for Energy Engineering and Power Technology](http://www.scimagojr.com/countryrank.php?category=2102) from the file `scimagojr-3.xlsx`, which ranks countries based on their journal contributions in the aforementioned area. Call this DataFrame **ScimEn**.
#
# Join the three datasets: GDP, Energy, and ScimEn into a new dataset (using the intersection of country names). Use only the last 10 years (2006-2015) of GDP data and only the top 15 countries by Scimagojr 'Rank' (Rank 1 through 15).
#
# The index of this DataFrame should be the name of the country, and the columns should be ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations',
#        'Citations per document', 'H index', 'Energy Supply',
#        'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015'].
#
# *This function should return a DataFrame with 20 columns and 15 entries.*

# %%
import pandas as pd
import numpy as np
import re

def get_energy():
    energy = pd.read_excel('Energy Indicators.xls', sheetname = 'Energy', header = 15, skip_footer = 38)
    energy.drop(['Unnamed: 0','Unnamed: 1'], axis = 1, inplace = True)
    energy.rename(columns = {'Unnamed: 2' : 'Country', 'Renewable Electricity Production' : '% Renewable'},inplace = True)
    energy.drop(0, axis = 0, inplace = True)
    energy.replace('...', np.nan, inplace = True)

    val = '[a-zA-Z,\s]+'
    l = []
    for i in energy['Country']:
        res = re.search(val,i)
        s = res.group(0)
        l.append(s)
    energy['Country'] = l

    con_energy = energy['Energy Supply']
    con_energy *=  1000000
    energy.fillna(value = np.nan , inplace = True)
    energy.replace({"Republic of Korea": "South Korea",
                 "United States of America": "United States",
                 "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                 "China, Hong Kong Special Administrative Region": "Hong Kong",
                 "Iran ": "Iran"}, inplace = True)
    energy = energy.set_index('Country')
    return energy

def get_GDP():
    GDP = pd.read_csv('world_bank.csv',header = 4)
    GDP.rename(columns = {'Country Name' : 'Country'}, inplace = True)
    GDP.replace({"Korea, Rep.": "South Korea", "Iran, Islamic Rep.": "Iran","Hong Kong SAR, China": "Hong Kong"}, inplace = True)
    GDP.drop(GDP.columns[1:50],axis = 1,inplace = True)
    GDP = GDP.set_index('Country')
    return GDP

def get_ScimEn():
    ScimEn = pd.read_excel('scimagojr-3.xlsx')
    ScimEn = ScimEn[ScimEn['Rank'] < 16]
    ScimEn =ScimEn.set_index('Country')
    return ScimEn

def answer_one():
    energy = get_energy()
    GDP = get_GDP()
    ScimEn = get_ScimEn()
    pre = pd.merge(ScimEn, energy, how = 'inner', left_index=True, right_index=True )
    final = pd.merge(pre, GDP, how = 'inner', left_index=True, right_index=True)
    final.sort(columns = 'Rank', axis = 0, ascending=True, inplace = True)
    return final

final = answer_one()
# Out:
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:51: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
final
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, China to Brazil
# Data columns (total 20 columns):
# Rank                        15 non-null int64
# Documents                   15 non-null int64
# Citable documents           15 non-null int64
# Citations                   15 non-null int64
# Self-citations              15 non-null int64
# Citations per document      15 non-null float64
# H index                     15 non-null int64
# Energy Supply               15 non-null float64
# Energy Supply per capita    15 non-null float64
# % Renewable                 15 non-null float64
# 2006                        15 non-null float64
# 2007                        15 non-null float64
# 2008                        15 non-null float64
# 2009                        15 non-null float64
# 2010                        15 non-null float64
# 2011                        15 non-null float64
# 2012                        15 non-null float64
# 2013                        15 non-null float64
# ...

# %% [markdown]
# Assignment 3 Question 2

# %% [markdown]
# ### Question 2 (6.6%)
# The previous question joined three datasets then reduced this to just the top 15 entries. When you joined the datasets, but before you reduced this to the top 15 items, how many entries did you lose?
#
# *This function should return a single number.*

# %%
# %%HTML
# <svg width="800" height="300">
#   <circle cx="150" cy="180" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="blue" />
#   <circle cx="200" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="red" />
#   <circle cx="100" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="green" />
#   <line x1="150" y1="125" x2="300" y2="150" stroke="black" stroke-width="2" fill="black" stroke-dasharray="5,3"/>
#   <text  x="300" y="165" font-family="Verdana" font-size="35">Everything but this!</text>
# </svg>
# Out:
# <svg width="800" height="300">
#   <circle cx="150" cy="180" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="blue" />
#   <circle cx="200" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="red" />
#   <circle cx="100" cy="100" r="80" fill-opacity="0.2" stroke="black" stroke-width="2" fill="green" />
#   <line x1="150" y1="125" x2="300" y2="150" stroke="black" stroke-width="2" fill="black" stroke-dasharray="5,3"/>
#   <text  x="300" y="165" font-family="Verdana" font-size="35">Everything but this!</text>
# </svg>

# %%
import pandas as pd
import numpy as np
import re

def answer_two():
    energy = pd.read_excel('Energy Indicators.xls', sheetname = 'Energy', header = 15, skip_footer = 38)
    energy.drop(['Unnamed: 0','Unnamed: 1'], axis = 1, inplace = True)
    energy.rename(columns = {'Unnamed: 2' : 'Country', 'Renewable Electricity Production' : '% Renewable'},inplace = True)
    energy.drop(0, axis = 0, inplace = True)
    energy.replace('...', np.nan, inplace = True)

    val = '[a-zA-Z,\s]+'
    l = []
    for i in energy['Country']:
        res = re.search(val,i)
        s = res.group(0)
        l.append(s)
    energy['Country'] = l

    con_energy = energy['Energy Supply']
    con_energy *=  1000000
    energy.fillna(value = np.nan , inplace = True)
    energy.replace({"Republic of Korea": "South Korea",
                 "United States of America": "United States",
                 "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                 "China, Hong Kong Special Administrative Region": "Hong Kong",
                 "Iran ": "Iran"}, inplace = True)
    energy = energy.set_index('Country')

    GDP = pd.read_csv('world_bank.csv',header = 4)
    GDP.rename(columns = {'Country Name' : 'Country'}, inplace = True)
    GDP.replace({"Korea, Rep.": "South Korea", "Iran, Islamic Rep.": "Iran","Hong Kong SAR, China": "Hong Kong"}, inplace = True)
    GDP.drop(GDP.columns[1:50],axis = 1,inplace = True)
    GDP = GDP.set_index('Country')

    ScimEn = pd.read_excel('scimagojr-3.xlsx')
    ScimEn = ScimEn[ScimEn['Rank'] < 16]
    ScimEn =ScimEn.set_index('Country')    


    s1 = set(energy.index)
    s2 = set(GDP.index)
    s3 = set(ScimEn.index)
    common_in_all = (s1.intersection(s2)).intersection(s3)
    common_in_all
    all_the_country = (s1.union(s2)).union(s3)
    all_the_country
    excluding_intersection = all_the_country - common_in_all
    excluding_intersection = list(excluding_intersection)
    return len(excluding_intersection)
    #return 156

answer_two()
# Out:
# 292

# %% [markdown]
# Assignment 3 Question 3

# %% [markdown]
# ### Question 3 (6.6%)
# What is the average GDP over the last 10 years for each country? (exclude missing values from this calculation.)
#
# *This function should return a Series named `avgGDP` with 15 countries and their average GDP sorted in descending order.*

# %%
def average_calc(ala_df):
    data = ala_df[['2006',
                  '2007',
                  '2008',
                  '2009',
                  '2010',
                  '2011',
                  '2012',
                  '2013',
                  '2014',
                  '2015',]]
    data.dropna(inplace = True)
    return np.average(data)

avgGDP = final.apply(average_calc,axis = 1)
avgGDP.sort(axis=0, ascending=False, inplace = True)
avgGDP
# Out:
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:16: FutureWarning: sort is deprecated, use sort_values(inplace=True) for INPLACE sorting
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# dtype: float64

# %%
l1 = []
for i in final.index:
    l = final.ix[i,final.columns[10:]].mean()
    l1.append(l)
final['avgGDP'] = l1
final.sort(columns = 'avgGDP',axis = 0, ascending = False, inplace = True)
# Out:
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)

# %%
final['avgGDP']
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# Name: avgGDP, dtype: float64

# %% [markdown]
# ### Question 4 (6.6%)
# By how much had the GDP changed over the 10 year span for the country with the 6th largest average GDP?
#
# *This function should return a single number.*

# %%
def gdpchange(ala_final):
    data1 = ala_final[['2006',
                     '2015']]
    ala_final['diff'] = data1['2015'] - data1['2006']
    return ala_final
    

num = final.apply(gdpchange, axis = 1)
a = num.ix[5,21]
a
# Out:
# 246702696075.3999

# %%
def answer_three():
    final = answer_one()
    l1 = []
    for i in final.index:
        l = final.ix[i,final.columns[10:]].mean()
        l1.append(l)
    final['avgGDP'] = l1
    final.sort(columns = 'avgGDP',axis = 0, ascending = False, inplace = True)
    return final

def answer_four():
    final1 = answer_three()
    l2 = []
    for j in final1.index:
        k = ((final1.ix[j,19]) - (final1.ix[j,10]))
        l2.append(k)
    final1['diffGDP'] = l2    
    return final1.ix[5,21]

answer_four()
# Out:
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:51: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:8: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# 246702696075.3999

# %% [markdown]
# ### Question 5 (6.6%)
# What is the mean `Energy Supply per Capita`?
#
# *This function should return a single number.*

# %%
def answer_five():
    final = answer_one()
    return final['Energy Supply per capita'].mean()

answer_five()
# Out:
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:51: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# 157.6

# %% [markdown]
# ### Question 6 (6.6%)
# What country has the maximum % Renewable and what is the percentage?
#
# *This function should return a tuple with the name of the country and the percentage.*

# %%
def answer_six():
    Top15 = answer_one()
    max_value = Top15['% Renewable'].max()  
    hig_rene = Top15['% Renewable'].idxmax()  
    return hig_rene, max_value

answer_six()
# Out:
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:51: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# ('Brazil', 69.648030000000006)

# %% [markdown]
# ### Question 7 (6.6%)
# Create a new column that is the ratio of Self-Citations to Total Citations.
# What is the maximum value for this new column, and what country has the highest ratio?
#
# *This function should return a tuple with the name of the country and the ratio.*

# %%
def answer_seven():
    Top15 = answer_one()
    sum_of_cit = Top15['Self-citations'].sum()
    Top15['ratio'] = Top15['Self-citations']/ Top15['Citations']
    max_value_cit = Top15['ratio'].max()
    max_ratio_country = Top15['ratio'].idxmax()
    return max_ratio_country,max_value_cit

answer_seven()
# Out:
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:51: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# ('China', 0.68931261793894216)

# %% [markdown]
# ### Question 8 (6.6%)
#
# Create a column that estimates the population using Energy Supply and Energy Supply per capita.
# What is the third most populous country according to this estimate?
#
# *This function should return a single string value.*

# %%
def answer_eight():
    Top15 = answer_one()
    Top15['Estimate'] = Top15['Energy Supply'] / Top15['Energy Supply per capita']
    Top15.sort(columns = 'Estimate', inplace = True)
    a = Top15['Estimate'][-3]
    b = list(np.where(Top15['Estimate'] == a)[0])
    c = Top15.iloc[b]
    d = Top15.iloc[b].index.tolist()
    return d[0]

answer_eight()
# Out:
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:51: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# 'United States'

# %% [markdown]
# ### Question 9 (6.6%)
# Create a column that estimates the number of citable documents per person.
# What is the correlation between the number of citable documents per capita and the energy supply per capita? Use the `.corr()` method, (Pearson's correlation).
#
# *This function should return a single number.*
#
# *(Optional: Use the built-in function `plot9()` to visualize the relationship between Energy Supply per Capita vs. Citable docs per Capita)*

# %%
def answer_nine():
    Top15 = answer_one()
    Top15['Estimate'] = Top15['Energy Supply'] / Top15['Energy Supply per capita']
    Top15['No of citable'] = Top15['Citable documents'] / Top15['Estimate']
    result = Top15['No of citable'].corr(Top15['Energy Supply per capita'])
    return result

answer_nine()
# Out:
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:51: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# 0.79400104354429446

# %% [markdown]
# ### Question 10 (6.6%)
# Create a new column with a 1 if the country's % Renewable value is at or above the median for all countries in the top 15, and a 0 if the country's % Renewable value is below the median.
#
# *This function should return a series named `HighRenew` whose index is the country name sorted in ascending order of rank.*

# %%
def answer_ten():
    Top15 = answer_one()
    median_per = Top15['% Renewable'].median()
    #print(median_per)
    Top15['HighRenew'] = [1 if i >= median_per else 0 for i in Top15['% Renewable']]
    return Top15['HighRenew']#,Top15['% Renewable']

answer_ten()
# Out:
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:51: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# Country
# China                 1
# United States         0
# Japan                 0
# United Kingdom        0
# Russian Federation    1
# Canada                1
# Germany               1
# India                 0
# France                1
# South Korea           0
# Italy                 1
# Spain                 1
# Iran                  0
# Australia             0
# Brazil                1
# Name: HighRenew, dtype: int64

# %% [markdown]
# ### Question 11 (6.6%)
# Use the following dictionary to group the Countries by Continent, then create a dateframe that displays the sample size (the number of countries in each continent bin), and the sum, mean, and std deviation for the estimated population of each country.
#
# ```python
# ContinentDict  = {'China':'Asia',
#                   'United States':'North America',
#                   'Japan':'Asia',
#                   'United Kingdom':'Europe',
#                   'Russian Federation':'Europe',
#                   'Canada':'North America',
#                   'Germany':'Europe',
#                   'India':'Asia',
#                   'France':'Europe',
#                   'South Korea':'Asia',
#                   'Italy':'Europe',
#                   'Spain':'Europe',
#                   'Iran':'Asia',
#                   'Australia':'Australia',
#                   'Brazil':'South America'}
# ```
#
# *This function should return a DataFrame with index named Continent `['Asia', 'Australia', 'Europe', 'North America', 'South America']` and columns `['size', 'sum', 'mean', 'std']`*

# %%
def answer_eleven():
    df = answer_one()
    df.reset_index(inplace = True)
    ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}
    key = list(ContinentDict.values())
    value = list(ContinentDict.keys())
    s = pd.Series(value, index = key)
    df1 = pd.DataFrame(s)
    df1.rename(columns = {0 : 'Country'},inplace = True)
    df1.reset_index(inplace = True)
    df2 = pd.merge(df1, df, how = 'left', left_on = 'Country', right_on = 'Country' )
    df3 = df2[['index', 'Country', 'Energy Supply', 'Energy Supply per capita']]
    df3['Pop_estimate'] = df3['Energy Supply'] / df3['Energy Supply per capita']
    df3.drop(['Energy Supply', 'Energy Supply per capita'], axis = 1, inplace = True)
    df4 = df3.groupby('index')['Pop_estimate'].agg({'size': np.size, 'sum' : np.sum, 'mean' : np.average, 'std' : np.std})  
    return df4

answer_eleven()
# Out:
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:51: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\kkv1\AppData\Local\Continuum\Anaconda3\lib\site-packages\ipykernel\__main__.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                         sum          mean           std  size
# index
# Asia           2.898666e+09  5.797333e+08  6.790979e+08   5.0
# ...

# %% [markdown]
# ### Date Functionality in Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Timestamp

# %%
pd.Timestamp('16/1/2016 10:05AM')
# Out:
# Timestamp('2016-01-16 10:05:00')

# %%
pd.Timestamp('16/1/2016')
# Out:
# Timestamp('2016-01-16 00:00:00')

# %% [markdown]
# If  time is not mentioned then by default it takes 00:00:00

# %%
pd.Timestamp('2016')
# Out:
# Timestamp('2016-01-01 00:00:00')

# %% [markdown]
# If date and time are not specified while creating a timestamp, then by default it takes 'YYYYY-01-01 00:00:00'

# %%
pd.Timestamp('9/16/2016 22:05')
# Out:
# Timestamp('2016-09-16 22:05:00')

# %% [markdown]
# Time in case of a Timeestamp function can be in 24 hour format or it can be in AM PM.
#
# If 24 hour format is not taken and AM or PM is not mentioned specifically then by detalut it takes as AM

# %%
pd.Timestamp('9/1/2016 10:05')
# Out:
# Timestamp('2016-09-01 10:05:00')

# %%
pd.Timestamp('9/1/2016 10:05PM')
# Out:
# Timestamp('2016-09-01 22:05:00')

# %% [markdown]
# If PM is mentioned specifically in case of a Timestamp then the return type will have the time in 24 hr format, i.e. in other words the pd.Timestamp follows 24 hours time format

# %%
pd.Timestamp('9/1/1 10:05PM')
# Out:
# Timestamp('2001-09-01 22:05:00')

# %%
pd.Timestamp('10:05PM')
# Out:
# Timestamp('2017-03-27 22:05:00')

# %% [markdown]
# In case of a pd.Timestamp if only the time is given as shon above the it will take the system date along with the Time specified as how in above example.

# %%
pd.Timestamp('10:05PM 25/3/1984')
# Out:
# Timestamp('1984-03-25 22:05:00')

# %% [markdown]
# The argumets of the pd.Timestamp can also be time followed by the date

# %% [markdown]
# When ever a timestamp is executed the output is of the format YYYY-MM-DD HH:MM:SS

# %% [markdown]
# ### Period

# %%
pd.Period('2016')
# Out:
# Period('2016', 'A-DEC')

# %%
pd.Period('1/2016')
# Out:
# Period('2016-01', 'M')

# %%
pd.Period('3/5/2016')
# Out:
# Period('2016-03-05', 'D')

# %%
pd.Period('10:10AM')
# Out:
# Period('0001-01-01 10:10', 'T')

# %%
pd.Period('10:05PM 25/3/1984')
# Out:
# Period('1984-03-25 22:05', 'T')

# %%
pd.Period('10:05:12 PM 25/3/1984')
# Out:
# Period('1984-03-25 22:05:12', 'S')

# %% [markdown]
# ### DatetimeIndex

# %%
t1 = pd.Series(list('abc'), [pd.Timestamp('2016-09-01'), pd.Timestamp('2016-09-02'), pd.Timestamp('2016-09-03')])
t1
# Out:
# 2016-09-01    a
# 2016-09-02    b
# 2016-09-03    c
# dtype: object

# %%
type(t1.index)
# Out:
# pandas.tseries.index.DatetimeIndex

# %%
t5 = pd.Series(list('abc'), [pd.Timestamp('2016-09-01 04:32AM'), pd.Timestamp('2016-09-02'), pd.Timestamp('2016-09-03 04:32AM')])
t5
# Out:
# 2016-09-01 04:32:00    a
# 2016-09-02 00:00:00    b
# 2016-09-03 04:32:00    c
# dtype: object

# %% [markdown]
# ### PeriodIndex

# %%
t2 = pd.Series(list('def'), [pd.Period('2016-09'), pd.Period('2016-10'), pd.Period('2016-11')])
t2
# Out:
# 2016-09    d
# 2016-10    e
# 2016-11    f
# Freq: M, dtype: object

# %%
type(t2.index)
# Out:
# pandas.tseries.period.PeriodIndex

# %% [markdown]
# ### Converting to Datetime

# %%
np.random.randint(10, 100, (4,4))
# Out:
# array([[47, 50, 72, 45],
#        [40, 56, 53, 58],
#        [33, 19, 49, 58],
#        [15, 44, 55, 81]])

# %% [markdown]
# Here the third argument inside randint function is
#
# The number of rows, The number of columns

# %%
d1 = ['2 June 2013', 'Aug 29, 2014', '2015-06-26', '7/12/16']
ts3 = pd.DataFrame(np.random.randint(10, 100, (4,2)), index=d1, columns=list('ab'))
ts3
# Out:
#                a   b
# 2 June 2013   57  24
# Aug 29, 2014  53  75
# 2015-06-26    72  99
# 7/12/16       41  50

# %%
ts3.index = pd.to_datetime(ts3.index)
ts3
# Out:
#              a   b
# 2013-06-02  57  24
# 2014-08-29  53  75
# 2015-06-26  72  99
# 2016-07-12  41  50

# %%
pd.to_datetime('4.7.12', dayfirst=True)
# Out:
# Timestamp('2012-07-04 00:00:00')

# %%
pd.to_datetime('4.7.12', yearfirst=True)
# Out:
# Timestamp('2004-07-12 00:00:00')

# %%
pd.to_datetime('4.7.12')
# Out:
# Timestamp('2012-04-07 00:00:00')

# %% [markdown]
# ### Timedeltas

# %%
pd.Timestamp('9/3/2016')-pd.Timestamp('9/1/2016')
# Out:
# Timedelta('2 days 00:00:00')

# %%
pd.Timestamp('9/2/2016 8:10AM') + pd.Timedelta('12D 3H')
# Out:
# Timestamp('2016-09-14 11:10:00')

# %% [markdown]
# ### Working with Dates in a Dataframe

# %%
dates = pd.date_range('10-01-2016', periods=9, freq='2W-SUN')
dates
# Out:
# DatetimeIndex(['2016-10-02', '2016-10-16', '2016-10-30', '2016-11-13',
#                '2016-11-27', '2016-12-11', '2016-12-25', '2017-01-08',
#                '2017-01-22'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
dates_tim = pd.date_range('10-01-2016 04:32AM', periods=9, freq='2W-SUN')
dates_tim
# Out:
# DatetimeIndex(['2016-10-02 04:32:00', '2016-10-16 04:32:00',
#                '2016-10-30 04:32:00', '2016-11-13 04:32:00',
#                '2016-11-27 04:32:00', '2016-12-11 04:32:00',
#                '2016-12-25 04:32:00', '2017-01-08 04:32:00',
#                '2017-01-22 04:32:00'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
rng = pd.date_range('1/1/2011', periods=36, freq='H')
rng
# Out:
# DatetimeIndex(['2011-01-01 00:00:00', '2011-01-01 01:00:00',
#                '2011-01-01 02:00:00', '2011-01-01 03:00:00',
#                '2011-01-01 04:00:00', '2011-01-01 05:00:00',
#                '2011-01-01 06:00:00', '2011-01-01 07:00:00',
#                '2011-01-01 08:00:00', '2011-01-01 09:00:00',
#                '2011-01-01 10:00:00', '2011-01-01 11:00:00',
#                '2011-01-01 12:00:00', '2011-01-01 13:00:00',
#                '2011-01-01 14:00:00', '2011-01-01 15:00:00',
#                '2011-01-01 16:00:00', '2011-01-01 17:00:00',
#                '2011-01-01 18:00:00', '2011-01-01 19:00:00',
#                '2011-01-01 20:00:00', '2011-01-01 21:00:00',
#                '2011-01-01 22:00:00', '2011-01-01 23:00:00',
#                '2011-01-02 00:00:00', '2011-01-02 01:00:00',
#                '2011-01-02 02:00:00', '2011-01-02 03:00:00',
#                '2011-01-02 04:00:00', '2011-01-02 05:00:00',
# ...

# %%
df = pd.DataFrame({'Count 1': 100 + np.random.randint(-5, 10, 9).cumsum(),
                  'Count 2': 120 + np.random.randint(-5, 10, 9)}, index=dates)
df
# Out:
#             Count 1  Count 2
# 2016-10-02      101      116
# 2016-10-16      107      115
# 2016-10-30      111      124
# 2016-11-13      117      118
# 2016-11-27      121      116
# 2016-12-11      119      121
# 2016-12-25      127      124
# 2017-01-08      126      115
# 2017-01-22      124      128

# %%
pd.Timestamp('9/3/2016').weekday_name
# Out:
# 'Saturday'

# %%
pd.Timestamp('25/3/1984').weekday_name
# Out:
# 'Sunday'

# %%
pd.Timestamp('29/3/1990').weekday_name
# Out:
# 'Thursday'

# %%
pd.Timestamp('22/10/1990').weekday_name
# Out:
# 'Monday'

# %%
df.diff()
# Out:
#             Count 1  Count 2
# 2016-10-02      NaN      NaN
# 2016-10-16      6.0     -1.0
# 2016-10-30      4.0      9.0
# 2016-11-13      6.0     -6.0
# 2016-11-27      4.0     -2.0
# 2016-12-11     -2.0      5.0
# 2016-12-25      8.0      3.0
# 2017-01-08     -1.0     -9.0
# 2017-01-22     -2.0     13.0

# %%
df.resample('M').mean()
# Out:
#                Count 1     Count 2
# 2016-10-31  106.333333  118.333333
# 2016-11-30  119.000000  117.000000
# 2016-12-31  123.000000  122.500000
# 2017-01-31  125.000000  121.500000

# %%
df['2017']
# Out:
#             Count 1  Count 2
# 2017-01-08      126      115
# 2017-01-22      124      128

# %%
df['2016-12']
# Out:
#             Count 1  Count 2
# 2016-12-11      119      121
# 2016-12-25      127      124

# %%
df['2016-12':]
# Out:
#             Count 1  Count 2
# 2016-12-11      119      121
# 2016-12-25      127      124
# 2017-01-08      126      115
# 2017-01-22      124      128

# %%
df.asfreq('W', method='ffill')
# Out:
#             Count 1  Count 2
# 2016-10-02      101      116
# 2016-10-09      101      116
# 2016-10-16      107      115
# 2016-10-23      107      115
# 2016-10-30      111      124
# 2016-11-06      111      124
# 2016-11-13      117      118
# 2016-11-20      117      118
# 2016-11-27      121      116
# 2016-12-04      121      116
# 2016-12-11      119      121
# 2016-12-18      119      121
# 2016-12-25      127      124
# 2017-01-01      127      124
# 2017-01-08      126      115
# 2017-01-15      126      115
# 2017-01-22      124      128

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df.plot()

# %%
df['Weekday'] = df.index.weekday_name

# %%
df
# Out:
#             Count 1  Count 2 Weekday
# 2016-10-02      101      116  Sunday
# 2016-10-16      107      115  Sunday
# 2016-10-30      111      124  Sunday
# 2016-11-13      117      118  Sunday
# 2016-11-27      121      116  Sunday
# 2016-12-11      119      121  Sunday
# 2016-12-25      127      124  Sunday
# 2017-01-08      126      115  Sunday
# 2017-01-22      124      128  Sunday

# %% [markdown]
# ### Distributions

# %% [markdown]
# #### Filpping a fair coin

# %%
np.random.binomial(1, 0.5)
# Out:
# 0

# %% [markdown]
# Here the first argument is the number of times you want to simulate the event

# %%
np.random.binomial(1000, 0.5)
# Out:
# 516

# %% [markdown]
# The result of probability should be betweeen 0 and 1 but here the result is we are getting  is greter than 1 and hence it needs to br rectified.

# %%
np.random.binomial(1000, 0.5)/1000
# Out:
# 0.482

# %% [markdown]
# So for a fair coin the probability of heads or tails is nearly 0.5

# %% [markdown]
# Flipping a fair coin 20 times and  getting a number greater than  or equal to 15
#
# use np.random.binomial(n,p,size) to do a 10000 simulations of fliping a fair coin 20 times, then seee what proportion of these simulations are greater than 15

# %%
s = np.random.binomial(20, 0.5, 10000)
a = (s>= 15).mean()
print(a)
# Out:
# 0.02

# %%
chance_of_tornado = 0.01/100
np.random.binomial(100000, chance_of_tornado)
# Out:
# 15

# %%
chance_of_tornado = 0.01

tornado_events = np.random.binomial(1, chance_of_tornado, 1000000)
#print(len(tornado_events))
two_days_in_a_row = 0
for j in range(1,len(tornado_events)-1):
    if tornado_events[j]==1 and tornado_events[j-1]==1:
        two_days_in_a_row+=1

print('{} tornadoes back to back in {} years'.format(two_days_in_a_row, 1000000/365))
# Out:
# 82 tornadoes back to back in 2739.72602739726 years

# %%
np.random.uniform(0, 1)
# Out:
# 0.53029258480886

# %%
np.random.normal(0.75)
# Out:
# 2.4863036620095085

# %%
np.random.normal()
# Out:
# 0.6742237909380921

# %% [markdown]
# Formula for standard deviation
# $$\sqrt{\frac{1}{N} \sum_{i=1}^N (x_i - \overline{x})^2}$$

# %%
distribution = np.random.normal(0.75,size=1000)
distribution
# Out:
# array([ 1.46328521,  0.60373096,  3.03193268,  1.2213814 ,  0.88889854,
#         2.89184599,  0.81237766,  1.81841832, -1.36307713, -0.16817478,
#         1.7053358 ,  1.20314496,  1.91879671,  1.89891271,  0.90311253,
#         0.57982677,  0.42817519,  1.86271786,  0.08063655,  0.24757476,
#         1.24584479,  1.74959317,  1.88618692,  2.00194457,  0.15567311,
#         0.61201301,  2.1743623 , -1.05631255, -0.7453461 , -0.335999  ,
#         0.89581984, -1.08754111, -0.35187602,  0.44759667,  0.38250305,
#         0.73328192,  1.18102974,  0.98739188,  2.06834034,  1.01672836,
#         1.31124686,  1.00027662,  2.15453552,  1.20854494,  1.69894122,
#        -0.10477822,  1.21565667,  0.08017509, -1.0777099 ,  0.1005196 ,
#         0.75061972,  0.45399709,  0.91637855, -0.74783805,  0.62643635,
#         1.77563343,  0.19330441,  2.06558928,  0.00567981,  1.04364506,
#         1.51889094,  0.92374069,  3.20135546,  2.22950109,  0.69988897,
# ...

# %%
distribution = np.random.normal(0.75,size=1000)

np.sqrt(np.sum((np.mean(distribution)-distribution)**2)/len(distribution))
# Out:
# 1.0043219111988619

# %%
np.std(distribution)
# Out:
# 1.0043219111988619

# %%
import scipy.stats as stats
stats.kurtosis(distribution)
# Out:
# 0.015173564759806801

# %%
stats.skew(distribution)
# Out:
# 0.05059145361421906

# %%
j = np.random.normal(1, 0.167)#/1000000
print(j)
# Out:
# 1.1774241883277696

# %%
pd.Timestamp('3/10/2017 ') + pd.Timedelta('90D')
# Out:
# Timestamp('2017-06-08 00:00:00')

# %% [markdown]
# ### Question 1

# %%
import re
f = open('university_towns.txt')


def getregionNames(reg):
    regionames = re.findall(r'\s*(.*?)\s*\(.*?\)(?:\[\d\])*', reg)
    return regionames

towns = {}
reg = ''
regionNames = []
for words in f.readlines():
    a = words.rstrip()
    if a.endswith('[edit]'):
        if len(towns) != 0:
            regionNames = getregionNames(reg)
            towns[statename] = regionNames
        towns.setdefault(a[:-6], [])
        statename = a[:-6]
        reg = ''
    else:
        reg+=words
regionNames = getregionNames(reg)
towns[statename] = regionNames 
mytup = [(x,y) for x in towns for y in towns[x]]
ls = []
lr = []
for i in mytup:
    ls.append(i[0])
    lr.append(i[1])
state = pd.Series(ls)
RegionName = pd.Series(lr)
df = pd.DataFrame([state,RegionName])
df1 = df.T
df1.rename(columns = {0 :'State', 1 : 'RegionName'}, inplace = True)
df1
# Out:
#               State                                         RegionName
# 0      Pennsylvania                                            Altoona
# 1      Pennsylvania                                           Annville
# 2      Pennsylvania                                          Bethlehem
# 3      Pennsylvania                                         Bloomsburg
# 4      Pennsylvania                                           Bradford
# 5      Pennsylvania                                         California
# 6      Pennsylvania                                           Carlisle
# 7      Pennsylvania  Cecil B. Moore, Philadelphia, also known as "T...
# 8      Pennsylvania                                            Clarion
# 9      Pennsylvania                                       Collegeville
# 10     Pennsylvania                                            Cresson
# 11     Pennsylvania                                   East Stroudsburg
# ...

# %%
df1.columns.tolist()
# Out:
# ['State', 'RegionName']
